# %% [markdown]
# # 文档转换

# %%
from docx import Document
from docx.shared import Inches
from docx import Document
from docx.shared import RGBColor
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import  Pt
from docx.oxml import OxmlElement
from docx.oxml.ns import  qn
from docx.shared import Inches
from docx.shared import Cm
from docx.text.run import Run
from docx.oxml.text.run import CT_R
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT, WD_LINE_SPACING

class Worker_doc:
    def __init__(self,list_data):
        self.data = {}
        self.list_data = list_data
        self.document = Document()
    def read_list_data(self,data):
        print("开始处理数据",data)
        if data['type'] == '一周天气预测':
            self.data = data
            self.head_run()
        elif data['type'] == '段落':
            self.data = data
            self.text_run()
        elif data['type'] == '列表':
            self.data = data
            self.list_run()
        elif data['type'] == '单图':
            self.data = data
            self.picture_run()
        elif data['type'] == '文件尾':
            self.data = data 
            self.foot_run()       
    def month_strto_num(self,start_month):
        monlist = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
        if start_month =='Jan':
            month = '1'
        elif start_month =='Feb':
            month = '2'
        elif start_month =='Mar':
            month = '3'
        elif start_month =='Apr':
            month = '4'
        elif start_month =='May':
            month = '5'
        elif start_month =='Jun':
            month = '6'
        elif start_month =='Jul':
            month = '7'
        elif start_month =='Aug':
            month = '8'
        elif start_month =='Sep':
            month = '9'
        elif start_month =='Oct':
            month = '10'
        elif start_month =='Nov':
            month = '11'
        elif start_month =='Dec':
            month = '12'
        return month 
    def head_run(self):
        # 获取数据
        year = self.data['time'][11:15]
        day = self.data['time'][8:10]
        hour = self.data['time'][16:18]
        minn = self.data['time'][19:21]
        month = self.month_strto_num(self.data['time'][4:7])
        # 文档标题
        head = self.document.add_heading()     
        head.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
        head.paragraph_format.space_before = Pt(0)
        run = head.add_run(self.data['type'],0)
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(255, 0, 0)
        run.font.size = Pt(48)                
        # 居中的期数
        p_index = self.document.add_paragraph()
        paragraph_format = p_index.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        run = p_index.add_run("第"+str(self.data['index'])+"期"+"("+year+")")
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        # 加入撰稿人
        p_writer = self.document.add_paragraph()
        paragraph_format = p_writer.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.RIGHT   #段落居右
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        run = p_writer.add_run("撰稿人："+self.data['writer']+"  ")
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        # 加入文件末尾
        p_foot = self.document.add_paragraph()
        paragraph_format = p_foot.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        run = p_foot.add_run(year+"年"+month+"月"+day+"日"+hour+"时")
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)        
        run = p_foot.add_run("    " + self.data['company']+"           "+"签发人:"+self.data['putter'])
        # run.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.RIGHT   #段落居中
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        self.document.add_picture('src/line-red.png')
    def text_run(self):
        # 文档标题
        head_1st = self.document.add_heading()     
        head_1st.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
        head_1st.paragraph_format.space_before = Pt(15)
        head_1st.paragraph_format.space_after = Pt(15)
        run = head_1st.add_run(self.data['title'][0],0)
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(18)
        # 文档附标题
        head_sub = self.document.add_heading()     
        head_sub.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT
        head_sub.paragraph_format.space_before = Pt(15)
        head_sub.paragraph_format.space_after = Pt(15)
        run = head_sub.add_run(self.data['subtitle'][0],0)
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(16)
        # 加入段落
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(15)  #设置段落前间距
        paragraph_format.space_after = Pt(15)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0.3)  #第一行缩进
        paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = self.data['text']
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
    def picture_run(self):
        
        # 保存
        if self.data['type'] == '单图':
            self.document.add_picture(self.data['png'], width=Inches(5.8))
            # 居中的标题
            p_index = self.document.add_paragraph()
            paragraph_format = p_index.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            paragraph_format.space_before = Pt(0)  #设置段落前间距
            paragraph_format.space_after = Pt(0)   #设置段落后间距
            run = p_index.add_run("图:" + "  "+ str(self.data['title']))
            run.font.name = u'楷体' 
            run._element.rPr.rFonts.set(qn('w:eastAsia'), u'楷体')
            run.font.color.rgb = RGBColor(0, 0, 0)
            run.font.size = Pt(14)
        elif self.data['type'] == '双图':
            png_obj = self.document.add_paragraph()
            paragraph_format = png_obj.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            run1 = png_obj.add_run()
            run1.add_picture(self.data['png1'],width=Inches(2.7))
            run2 = png_obj.add_run()
            run2.add_picture(self.data['png1'],width=Inches(2.7))            
            # 居中的标题
            p_index = self.document.add_paragraph()
            paragraph_format = p_index.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            paragraph_format.space_before = Pt(0)  #设置段落前间距
            paragraph_format.space_after = Pt(0)   #设置段落后间距
            run = p_index.add_run("图1:" + "  "+ str(self.data['title1']) +"图2:" + "  "+ str(self.data['title2']) )
            run.font.name = u'楷体' 
            run._element.rPr.rFonts.set(qn('w:eastAsia'), u'楷体')
            run.font.color.rgb = RGBColor(0, 0, 0)
            run.font.size = Pt(14)
        else :
            png_obj1 = self.document.add_paragraph()
            paragraph_format = png_obj1.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            paragraph_format.space_before = Pt(0)  #设置段落前间距
            paragraph_format.space_after = Pt(0)   #设置段落后间距
            run1 = png_obj1.add_run()
            run1.add_picture(self.data['png1'],width=Inches(2.7))
            run2 = png_obj1.add_run()
            run2.add_picture(self.data['png1'],width=Inches(2.7))   

            png_obj2 = self.document.add_paragraph()
            paragraph_format = png_obj2.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            paragraph_format.space_before = Pt(0)  #设置段落前间距
            paragraph_format.space_after = Pt(0)   #设置段落后间距
            run1 = png_obj2.add_run()
            run1.add_picture(self.data['png3'],width=Inches(2.7))
            run2 = png_obj2.add_run()
            run2.add_picture(self.data['png4'],width=Inches(2.7))  

            # 居中的标题
            p_index = self.document.add_paragraph()
            paragraph_format = p_index.paragraph_format  #创建段落格式对象
            paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
            paragraph_format.space_before = Pt(0)  #设置段落前间距
            paragraph_format.space_after = Pt(0)   #设置段落后间距
            run = p_index.add_run("图1:" + "  "+ str(self.data['title1']) +"图2:" + "  "+ str(self.data['title2']) + \
                 "图3:" + "  "+ str(self.data['title3']) +"图4:" + "  "+ str(self.data['title4']) )
            run.font.name = u'楷体' 
            run._element.rPr.rFonts.set(qn('w:eastAsia'), u'楷体')
            run.font.color.rgb = RGBColor(0, 0, 0)
            run.font.size = Pt(12.5) 
    def list_run(self):
        # 文档标题
        head_1st = self.document.add_heading()     
        head_1st.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT
        head_1st.paragraph_format.space_before = Pt(15)
        head_1st.paragraph_format.space_after = Pt(15)
        run = head_1st.add_run(self.data['title'][0],0)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        # 列表的第一列
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(6)  #设置段落前间距
        paragraph_format.space_after = Pt(6)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0.3)  #第一行缩进
        paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = self.data['text_list1']
        print(len(self.data['text_list1']))
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        # 列表的第一列
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(6)  #设置段落前间距
        paragraph_format.space_after = Pt(6)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0.3)  #第一行缩进
        paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = self.data['text_list1']
        print(len(self.data['text_list1']))
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)
        # 列表的第一列
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(6)  #设置段落前间距
        paragraph_format.space_after = Pt(6)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0.3)  #第一行缩进
        paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = self.data['text_list1']
        print(len(self.data['text_list1']))
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14)   
    def foot_run(self):
        # 保存
        png_obj = self.document.add_paragraph()
        paragraph_format = png_obj.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        run1 = png_obj.add_run()
        run1.add_picture(self.data['png1'],width=Inches(1.5))
        png_obj.add_run("     ")
        run2 = png_obj.add_run()
        run2.add_picture(self.data['png2'],width=Inches(1.5))  
        png_obj.add_run("     ")
        run3 = png_obj.add_run()
        run3.add_picture(self.data['png3'],width=Inches(1.5)) 
        # 添加标题
        p_index = self.document.add_paragraph()
        paragraph_format = p_index.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER   #段落居中对齐
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        blank_tab = "       "
        run = p_index.add_run(self.data['title1']+blank_tab+ self.data['title2'] + blank_tab + self.data['title3'] )
        run.font.name = u'宋体' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'宋体')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(14) 
        # 添加黑色实线
        self.document.add_picture('src/line-black.png')
        # 呈
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0)  #第一行缩进
        # paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = "呈:" + self.data['service_name']
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(12.5)
        # 送
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0)  #第一行缩进
        # paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = "送:" + self.data['service_unity']
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(12.5)
        # 发
        p_main = self.document.add_paragraph()
        paragraph_format = p_main.paragraph_format  #创建段落格式对象
        paragraph_format.alignment = WD_ALIGN_PARAGRAPH.LEFT  #段落居左
        paragraph_format.space_before = Pt(0)  #设置段落前间距
        paragraph_format.space_after = Pt(0)   #设置段落后间距
        paragraph_format.first_line_indent = Inches(0)  #第一行缩进
        # paragraph_format.line_spacing_rule = WD_LINE_SPACING.ONE_POINT_FIVE # 1.5倍行距
        context_main = "发:" + self.data['recive_unity']
        run = p_main.add_run(context_main)
        run.font.name = u'仿宋_GB2312' 
        run._element.rPr.rFonts.set(qn('w:eastAsia'), u'仿宋_GB2312')
        run.font.color.rgb = RGBColor(0, 0, 0)
        run.font.size = Pt(12.5)
    def doc_save(self):
        self.document.save('word/台州市气象局_一周天气_第1期.pdf')
    def doc_run(self):
        for i in self.list_data:
            self.read_list_data(i)
        self.doc_save()
    def doc_2pdf_png(self):
        pass

        
    

list_data = [
    {  # 文件头
        "type": "一周天气预测",
        "company": "台州市气象台",
        "writer": "翁之梅",
        "putter": "高丽",
        "index": 15,
        "time": 'Wed Mar 01 2022 19:18:00 GMT+0800 (中国标准时间)'

    },
    {  # 文档内容
        "type": "段落",
        "title": ["本周后期强冷空气影响，全市有严重冰冻", 1, 2, 3],
        "subtitle":["短信内容", 1, 2, 3],
        "text":"本周前期天气阴沉，周后期强冷空气影响转晴冷天气，全市有严重冰冻。今天、明天阴有分散性小雨，最高气温12～14度；后天多云到阴，夜里～周四受强冷空气影响有明显降温、大风和弱雨雪过程，预计日平均气温过程降温幅度可达8～10度，后天夜里部分地区有小雨夹雪或雪，山区有小雪；周五～周日天气晴冷，其中周五、周六早晨北部地区降至零下6～零下8度，山区零下9～零下12度，其它地区零下4～零下6度，全市有严重冰冻，须注意防寒保暖。另外，周二沿海风力8～9级，周三夜里～周四沿海和内陆分别有8～10级和6～8级偏北大风。"
    },
    {  # 文档列表
        "type": "列表",
        "title": ["台州市主城区具体天气预报如下：", 1, 2, 3],
        "subtitle":["短信内容", 1, 2, 3],
        "text_list1":"4日（周一）：阴，部分地区有时有小雨              9～14度",
        "text_list2":"4日（周一）：阴，部分地区有时有小雨        9～14度",
        "text_list3":"4日（周一）：阴，部分地区有时有小雨        9～14度",
        "text_list4":"4日（周一）：阴，部分地区有时有小雨        9～14度",
        "text_list5":"4日（周一）：阴，部分地区有时有小雨        9～14度",
        "text_list6":"4日（周一）：阴，部分地区有时有小雨        9～14度",

    },
    {  # 图片列表
        "type": "单图",
        "title": "台州市气象台",
        "png": 'src/pre_test.png'
    },
    {
        "type": "文件尾",
        "title1": "微信宣传",
        "png1": 'src/二维码.png',
        "title2": "气象台宣传",
        "png2": 'src/二维码.png',
        "title3": "浙政钉宣传",
        "png3": 'src/二维码.png',
        "service_name": '宋伟2、李渊、小王、张三',
        "service_unity": '气象台、玉环市气象局、水利局、气象台、玉环市气象局、水利局、气象台、玉环市气象局、水利局、玉环市气象局、水利局、气象台、玉环市气象局、水利局、玉环市气象局、水利局、气象台、玉环市气象局、水利局、玉环市气象局、水利局、气象台、玉环市气象局、水利局',
        "recive_unity": '气象台、玉环市气象局、水利局、玉环市气象局、水利局'
    }
]

a = Worker_doc(list_data)
a.doc_run()
# Out:
# 开始处理数据 {'type': '一周天气预测', 'company': '台州市气象台', 'writer': '翁之梅', 'putter': '高丽', 'index': 15, 'time': 'Wed Mar 01 2022 19:18:00 GMT+0800 (中国标准时间)'}
# 开始处理数据 {'type': '段落', 'title': ['本周后期强冷空气影响，全市有严重冰冻', 1, 2, 3], 'subtitle': ['短信内容', 1, 2, 3], 'text': '本周前期天气阴沉，周后期强冷空气影响转晴冷天气，全市有严重冰冻。今天、明天阴有分散性小雨，最高气温12～14度；后天多云到阴，夜里～周四受强冷空气影响有明显降温、大风和弱雨雪过程，预计日平均气温过程降温幅度可达8～10度，后天夜里部分地区有小雨夹雪或雪，山区有小雪；周五～周日天气晴冷，其中周五、周六早晨北部地区降至零下6～零下8度，山区零下9～零下12度，其它地区零下4～零下6度，全市有严重冰冻，须注意防寒保暖。另外，周二沿海风力8～9级，周三夜里～周四沿海和内陆分别有8～10级和6～8级偏北大风。'}
# 开始处理数据 {'type': '列表', 'title': ['台州市主城区具体天气预报如下：', 1, 2, 3], 'subtitle': ['短信内容', 1, 2, 3], 'text_list1': '4日（周一）：阴，部分地区有时有小雨              9～14度', 'text_list2': '4日（周一）：阴，部分地区有时有小雨        9～14度', 'text_list3': '4日（周一）：阴，部分地区有时有小雨        9～14度', 'text_list4': '4日（周一）：阴，部分地区有时有小雨        9～14度', 'text_list5': '4日（周一）：阴，部分地区有时有小雨        9～14度', 'text_list6': '4日（周一）：阴，部分地区有时有小雨        9～14度'}
# 37
# 37
# 37
# 开始处理数据 {'type': '单图', 'title': '台州市气象台', 'png': 'src/pre_test.png'}
# ...
