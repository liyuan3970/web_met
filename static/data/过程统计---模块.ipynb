# %% [markdown]
# # 自动站数据的类

# %% [markdown]
# ## 自动站模块的最新版23年4月27日

# %%
class zdz_data:
    def __init__(self, start, end):
        self.start = start
        self.end = end  
    def read_csv(self):
        '''
        1.数据读取---此方法为测试方法
        2.数据分段---每天
        3.每天统计
        '''
        #         station_Mws = pd.read_csv("Mws_15.csv")
        #         station_Aws = pd.read_csv("Aws_15.csv")
        #         station_all = pd.concat([station_Aws, station_Mws])
        # station_all = pd.read_csv("data_zdz_height.csv")
        station_all = pd.read_csv("static/data/data_zdz_height.csv")
        return station_all
    def sql_data(self):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="ZJSZDZDB")
        start = self.start 
        end = self.end 
        #print(start,end)
        sql_location = "select b.StationName,b.county,b.Town,b.lat,b.lon,b.IIiii,b.Height,tTime,dFy,fFy,T,Tx,Tn,VV,RR from\
            TAB_Mws2019 as a left join TAB_StationInfo as b on a.IIiii=b.IIiii where\
            (b.IIiii in (select IIiii from TAB_StationInfo where(City = '台州') and tTime between"
        sql_location = sql_location + " " + "'" +  start + "'" +  "  " + "and" + " " + "'" +  end + "'" + "))"
        df_location = pd.read_sql(sql_location , con=conn)
        return df_location
    def return_daylist(self):
        '''
        返回日期列表
        '''
        dates = []
        #         dt = datetime.datetime.strptime(self.start, "%Y-%m-%d")
        dt = dtt.datetime.strptime(self.start[0:10], "%Y-%m-%d")
        date = self.start[:10]
        yesday = dt+dtt.timedelta(-1)
        dates.append(yesday.strftime("%Y-%m-%d")[:10])
        while date <= self.end[:10]:
            dates.append(date)
            dt = dt + dtt.timedelta(1)
            date = dt.strftime("%Y-%m-%d")
        return dates
    def day_button(self,city,station_data):
        '''返回按钮组'''
        station_all = station_data
        dates = self.return_daylist()
        dailylist = []
        for i in range(len(dates)):
            daily = {
                "time":None,
                "rain":False,
                "wind":False,
                "tmax":False,
                "tmin":False,
                "view":False,
            }
            if i!=0:
                s_date = dates[i-1] + ' ' + '20:00'
                e_date = dates[i] + ' ' + '20:00'
                daily["time"] = dates[i]
                df_preday = station_all[(station_all['tTime'] >= s_date) & (station_all['tTime'] <= e_date)]
                # 统计标量
                temp_min = df_preday[(df_preday['Height'] < 6000) & (df_preday['T'] > -400)]['T'].min()
                temp_max = df_preday[(df_preday['Height'] < 6000) & (df_preday['T'] > -400)]['T'].max()
                vv = df_preday[(df_preday['VV'] > 0.1) & (df_preday['VV'] < 500)]['VV'].count()
                RR = df_preday[(df_preday['RR'] > 0.1) & (df_preday['RR'] < 8888)]['RR'].count()
                wind = df_preday[df_preday['fFy'] > 187]['fFy'].count()    
                if temp_min<0:
                    daily["tmin"] = True
                if temp_max>350:
                    daily["tmax"] = True
                if vv >0:
                    daily["view"] = True
                if RR >0:
                    daily["rain"] = True
                if wind >0:
                    daily["wind"] = True
                dailylist.append(daily)
        return dailylist
    def rain_data(self,start,end,station_data):
        '''返回点击绘图所需的数据'''
        # 采集数据 可以是sql
        station_all = station_data
        grouped_tTime = station_all.groupby('IIiii')
        points = []
        table_data = []  
        for i in grouped_tTime.size().index:
            data = grouped_tTime.get_group(i)
            RR = data[(data['RR'] > 0.0) & (data['RR'] < 8888)]['RR'].sum()/10.0
            if RR > 0:
                single = {
                    "type": "Feature",
                    "properties": {
                        "value": str(RR)
                    },
                    "geometry": {
                        "type": "Point",
                        "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                    }
                }
                points.append(single)  
                # 采集marker和表格的数据
                rain = data.sort_values(by="tTime")["RR"].to_list()
                time = data.sort_values(by="tTime")["tTime"].to_list()
                ## 自己定义表格的数据形式
                single_rain = {
                    "IIiii":data['IIiii'].iloc[0],
                    "county":data['county'].iloc[0],
                    "town":data['Town'].iloc[0],
                    "StationName":data['StationName'].iloc[0],
                    "RR":RR,
                    "lat":data['lat'].iloc[0],
                    "lon":data['lon'].iloc[0],
                    "height":data['Height'].iloc[0],
                    "rain_list":rain,
                    "time_list":time
                }
                table_data.append(single_rain)  
        return points
    def index_data(self):
        '''返回所有数据'''
        city = "taizhou"
        #station_all = self.read_csv()
        station_all = self.sql_data()
        daily_btn_list = self.day_button(city,station_all)
        grouped_tTime = station_all.groupby('IIiii')
        table_data = []  
        points = []
        for i in grouped_tTime.size().index:
            data = grouped_tTime.get_group(i)
            time = data.sort_values(by="tTime")["tTime"].to_list()
            RR = data[(data['RR'] > 0.0) & (data['RR'] < 8888)]['RR'].sum()/10.0
            tmin = data[(data['T'] >-400) & (data['T'] < 8888)]['T'].min()/10.0
            tmax = data[(data['T'] >-400) & (data['T'] < 8888)]['T'].max()/10.0
            vv = data[(data['VV'] >0) & (data['VV'] < 1000)]['VV'].min()
            wind = data[data['fFy'] > 180]['fFy'].max()/10.0
            index =  data[data['fFy'] == data['fFy'].max()].index.tolist()[0]
            #print(index,"---",wind,"--",data['dFy'][index])
            #deg = data[data['fFy'] == data['fFy'].max()]['dFy'].iloc[0]
            deg = data['dFy'][index]
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(RR)
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                }
            }        
            # 雨
            if np.isnan(RR):
                RR=-9999.0
                rain = False
            else:
                # rain_data = {
                #     "type": "Feature",
                #     "properties": {
                #         "value": str(RR)
                #     },
                #     "geometry": {
                #         "type": "Point",
                #         "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                #     }
                # }
                # points.append(rain_data)
                rain = data.sort_values(by="tTime")["RR"].to_list()
            # 风
            if np.isnan(wind):
                wind=-9999.0
                fFy = False
                dFy = False
            else:
                fFy = data.sort_values(by="tTime")["fFy"].to_list()
                dFy = data.sort_values(by="tTime")["dFy"].to_list()
            # 温
            if np.isnan(tmax):
                tmax=-9999.0
                tx = False
            else:
                tx = data.sort_values(by="tTime")["Tx"].to_list()
            if np.isnan(tmin):
                tmin=-9999.0
                tn = False
            else:
                tn = data.sort_values(by="tTime")["Tn"].to_list()
            # 雾
            if np.isnan(vv):
                vv=-9999.0
                view = False
            else:
                view = data.sort_values(by="tTime")["VV"].to_list()
            single = {
                "IIiii":str(data['IIiii'].iloc[0]),
                "county":str(data['county'].iloc[0]),
                "town":str(data['Town'].iloc[0]),
                "StationName":str(data['StationName'].iloc[0]),
                "fFy":str(wind),
                "dFy":str(deg),
                "RR":str(RR),
                "Tx":str(tmax),
                "Tn":str(tmin),
                "VV":str(vv),
                "lat":str(data['lat'].iloc[0]),
                "lon":str(data['lon'].iloc[0]),
                "rain_list":rain,
                "tmax_list":tx,
                "tmin_list":tn,
                "fFy_list":fFy,
                "dFy_list":dFy,
                "view_list":view,
                "time_list":time
                }
            table_data.append(single)
        return table_data,points,daily_btn_list

# %% [markdown]
# ## 自动站数据库版本 23年4月27日

# %%
# %%time
import base64
import json
import os
from io import BytesIO
from math import isnan
import geopandas as gpd
import matplotlib.pyplot as plt
import netCDF4
import numpy as np
# import modin.pandas as pd
import pandas as pd
import shapefile
import xarray as xr
from affine import Affine
from matplotlib.patches import PathPatch
from matplotlib.path import Path
from mpl_toolkits.basemap import Basemap
from ncmaps import Cmaps
from rasterio import features
import xesmf as xe
import redis
from scipy.interpolate import griddata
from scipy.interpolate import interp1d
# import h5netcdf.legacyapi as netCDF4
os.environ["HDF5_USE_FILE_LOCKING"] = 'FALSE'
import datetime as dtt
from datetime import *
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
from pylab import *
from matplotlib.font_manager import FontProperties
import pymysql


class zdz_data:
    def __init__(self, start, end):
        self.start = start
        self.end = end  
    def sql_index(self):
        dailylist = self.day_button()
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        sql_location = f"""select lat,lon,sd.station_name, sd.station_no as station_no, sd.w_max as wind, max(w_dir) as w_dir,
        sum(p_total) as rain,
        min(if(vis>0,vis,9999)) as view ,
        min(t_min) as t_min ,
        max(t_max) as t_max ,
        sd.station_city as city,
        sd.station_town as town,
        sd.station_county as county
        from (select station_no,max(if(w_max>0,w_max,null)) as wind from station_data where (datetime between '{self.start}' and '{self.end}') group by station_no) as wind
        inner join station_data as sd on sd.station_no = wind.station_no where( sd.w_max = wind.wind and datetime between '{self.start}' and '{self.end}')
        group by sd.datetime, sd.station_no, sd.w_max,lat,lon,station_name,station_city,station_town,station_county"""
        df_location = pd.read_sql(sql_location , con=conn)  
        print(df_location)
        point = []  
        table_data = []
        for i in range(len(df_location)):
            # 面雨量
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(df_location.iloc[i,6])
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [df_location.iloc[i,1], df_location.iloc[i,0]]
                }
            } 
            point.append(rain_data)
            # 数据表
            single = {
                "IIiii":str(df_location.iloc[i,3]),
                "city":str(df_location.iloc[i,10]),
                "town":str(df_location.iloc[i,11]),
                "county":str(df_location.iloc[i,12]),
                "StationName":str(df_location.iloc[i,2]),
                "fFy":str(df_location.iloc[i,4]),
                "dFy":str(df_location.iloc[i,5]),
                "RR":str(df_location.iloc[i,6]),
                "Tx":str(df_location.iloc[i,9]),
                "Tn":str(df_location.iloc[i,8]),
                "VV":str(df_location.iloc[i,7]),
                "lat":str(df_location.iloc[i,0]),
                "lon":str(df_location.iloc[i,1]),
                }
            table_data.append(single)
        return table_data,point,dailylist
    def day_button(self):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        start = self.start 
        end = self.end 
        select_rain = 'p_total' 
        select_tmax = 't_max'
        select_tmin = 't_min'
        select_wind = 'w_max'
        select_vis = 'vis'
        select_lat = 'lat'
        select_lon = 'lon'
        db_table = 'station_data'
        sql = f"""select datetime,station_no,
        {select_rain} ,{select_tmax},{select_tmin} ,{select_wind},{select_vis} 
        from {db_table}
        where (datetime between "{start}" and "{end}")"""
        df_location = pd.read_sql(sql , con=conn)
        df_location['day'] = df_location['datetime'].dt.day
        df_location['year'] = df_location['datetime'].dt.year
        df_location['month'] = df_location['datetime'].dt.month
        datagroup = df_location.groupby(['month','day','year'])
        dailylist = []
        for i in datagroup.size().index:
            df = datagroup.get_group(i)
            daily = {
                "time":str(df['datetime'].dt.year.iloc[0]) +"年"+ str(df['datetime'].dt.month.iloc[0]) + "月" + str(df['datetime'].dt.day.iloc[0]) + "日",
                "rain":False,
                "wind":False,
                "tmax":False,
                "tmin":False,
                "view":False,
            }
            if df[(df['vis']>0) & (df['vis']<750)]['vis'].count() >0:
                daily['view'] = True
            if df[df['t_max']>370]['t_max'].count()>0:
                daily['tmax'] = True
            if df[df['t_min']<-100]['t_min'].count() >0:
                daily['tmin'] = True
            if df[df['w_max']>108]['w_max'].count() >0:
                daily['wind'] = True
            if df[df['p_total']>0]['p_total'].count() >0:
                daily['rain'] = True
            dailylist.append(daily)
        return dailylist
    def sql_wind(self,start,end):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        sql_location = f"""select lat,lon,sd.station_name, sd.station_no as station_no, sd.w_max as wind, max(w_dir) as w_dir from
        (select station_no,max(if(w_max>0,w_max,null)) as wind from station_data where (datetime between '{start}' and '{end}') group by station_no) as wind
        inner join station_data as sd on sd.station_no = wind.station_no where( sd.w_max = wind.wind and datetime between '{start}' and '{end}')
        group by sd.datetime, sd.station_no, sd.w_max,lat,lon,station_name"""
        df_location = pd.read_sql(sql_location , con=conn)
        point = []  
        table_data = []
        for i in range(len(df_location)):
            # 面雨量
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(df_location.iloc[i,4])
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [df_location.iloc[i,1], df_location.iloc[i,0]]
                }
            } 
            point.append(rain_data)
            # 数据表
            single = {
                "IIiii":str(df_location.iloc[i,3]),
                "county":"台州市",
                "start":start,
                "end":end,
                "StationName":str(df_location.iloc[i,2]),
                "fFy":str(df_location.iloc[i,4]),
                "dFy":str(df_location.iloc[i,5]),
                "lat":str(df_location.iloc[i,0]),
                "lon":str(df_location.iloc[i,1]),
                }
            table_data.append(single)       
        return table_data , point
    def sql_rain(self,start,end):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        sql_location = f"""select lat,lon, station_name,station_no,
        sum(p_total>0) as rain
        from station_data where( datetime between '{start}' and '{end}' ) 
        group by lat,lon, station_name,station_no"""
        df_location = pd.read_sql(sql_location , con=conn)
        point = []  
        table_data = []
        for i in range(len(df_location)):
            # 面雨量
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(df_location.iloc[i,4])
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [df_location.iloc[i,1], df_location.iloc[i,0]]
                }
            } 
            point.append(rain_data)
            # 数据表
            single = {
                "IIiii":str(df_location.iloc[i,3]),
                "county":"台州市",
                "start":start,
                "end":end,
                "StationName":str(df_location.iloc[i,2]),
                "RR":str(df_location.iloc[i,4]),
                "lat":str(df_location.iloc[i,0]),
                "lon":str(df_location.iloc[i,1]),
                }
            table_data.append(single)       
        return table_data , point      
    def sql_temp(self,start,end,temp):
        if temp =="max":
            tempind = 5
        else:
            tempind = 4
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        sql_location = f"""select lat,lon, station_name,station_no,
        min(t_min) as t_min ,
        max(t_max) as t_max 
        from station_data where( datetime between '{start}' and '{end}' ) 
        group by lat,lon, station_name,station_no"""
        df_location = pd.read_sql(sql_location , con=conn)
        point = []  
        table_data = []
        for i in range(len(df_location)):
            # 面雨量
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(df_location.iloc[i,tempind])
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [df_location.iloc[i,1], df_location.iloc[i,0]]
                }
            } 
            point.append(rain_data)
            # 数据表
            single = {
                "IIiii":str(df_location.iloc[i,3]),
                "county":"台州市",
                "start":start,
                "end":end,
                "StationName":str(df_location.iloc[i,2]),
                "t_min":str(df_location.iloc[i,4]),
                "t_max":str(df_location.iloc[i,5]),
                "lat":str(df_location.iloc[i,0]),
                "lon":str(df_location.iloc[i,1]),
                }
            table_data.append(single)       
        return table_data , point 
    def sql_view(self,start,end):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="tzweb")
        sql_location = f"""select lat,lon, station_name,station_no,
        min(vis) as rain
        from station_data where( datetime between '{start}' and '{end}' ) 
        group by lat,lon, station_name,station_no"""
        df_location = pd.read_sql(sql_location , con=conn)
        point = []  
        table_data = []
        for i in range(len(df_location)):
            # 面雨量
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(df_location.iloc[i,4])
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [df_location.iloc[i,1], df_location.iloc[i,0]]
                }
            } 
            point.append(rain_data)
            # 数据表
            single = {
                "IIiii":str(df_location.iloc[i,3]),
                "county":"台州市",
                "start":start,
                "end":end,
                "StationName":str(df_location.iloc[i,2]),
                "VV":str(df_location.iloc[i,4]),
                "lat":str(df_location.iloc[i,0]),
                "lon":str(df_location.iloc[i,1]),
                }
            table_data.append(single)       
        return table_data,point
    def sql_click(self,start,end,station,click_type):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="ZJSZDZDB")
        if click_type!='wind':
            if station[0]!='K':
                sql_location = f"""select tTime,{click_type} from TAB_Aws2019 where ( IIiii={station} and tTime between '{start}' and '{end}')"""
            else:
                sql_location = f"""select tTime,{click_type} from TAB_Mws2019 where ( IIiii='{station}' and tTime between '{start}' and '{end}')"""
        else:
            if station[0]!='K':
                sql_location = f"""select tTime,dFy,fFy from TAB_Aws2019 where ( IIiii={station} and tTime between '{start}' and '{end}')"""
            else:
                sql_location = f"""select tTime,dFy,fFy from TAB_Mws2019 where ( IIiii='{station}' and tTime between '{start}' and '{end}')"""
        
        df_location = pd.read_sql(sql_location , con=conn) 
        time = df_location.sort_values(by="tTime")["tTime"].to_list() 
        if click_type == "wind":
            values = [df_location.sort_values(by="tTime")['fFy'].to_list(),df_location.sort_values(by="tTime")['dFy'].to_list()]
        else:
            values = df_location.sort_values(by="tTime")[click_type].to_list()     
        return time,values,click_type,station


# start = '2022-01-25 20:00'
# end = '2022-02-10 06:00'


start = '2019-06-25 10:00'
end = '2019-08-15 20:00'
sql_worker = zdz_data(start,end)
a , b, c= sql_worker.sql_index()
#sql_worker.sql_wind(start,end)
#sql_worker.sql_rain(start,end)
# sql_worker.sql_temp(start,end,"max")
# sql_worker.sql_view(start,end)

#############
# station,click_type = 'K8002','wind'
# sql_worker.sql_click(start,end,station,click_type)
# Out:
#            lat         lon station_name station_no   wind  w_dir    rain  \
# 0    28.850280  120.511700          大陈村      K8907  104.0  352.0    82.0
# 1    28.789720  120.933330         括苍山B      K8654   96.0  252.0    15.0
# 2    28.768000  120.627000          台创园      K8930   66.0   54.0     0.0
# 3    28.433333  119.483333           松阳      58645  161.0  299.0     3.0
# 4    29.800000  121.500000           鄞州      58562  236.0  233.0   117.0
# ..         ...         ...          ...        ...    ...    ...     ...
# 377  28.635830  120.807800         天顶茶场      K8949  284.0  358.0  3414.0
# 378  28.632780  120.903100          金竹寺      K8982  160.0  346.0     0.0
# 379  29.266667  120.216667           东阳      58558  192.0  308.0     7.0
# 380  28.450000  119.916667           丽水      58646  115.0  272.0     0.0
# 381  28.083333  119.133333           龙泉      58647  155.0  351.0   358.0
#
#         view  t_min  t_max city   town county
# 0     9999.0  228.0  364.0   台州    埠头镇    仙居县
# 1     9999.0  223.0  229.0   台州    括苍镇    临海市
# 2     9999.0  334.0  334.0   台州    田市镇    仙居县
# 3     5184.0  249.0  360.0   丽水   水南街道    松阳县
# 4     2472.0  255.0  362.0   宁波   石碶街道    鄞州区
# ..       ...    ...    ...  ...    ...    ...
# 377   9999.0  215.0  230.0   台州    上张乡    仙居县
# 378   9999.0  257.0  281.0   台州    朱溪镇    仙居县
# 379  16790.0  279.0  353.0   金华   吴宁街道    东阳市
# 380   9706.0  256.0  367.0   丽水  南明山街道    莲都区
# 381   4174.0  240.0  337.0   丽水   西街街道    龙泉市
#
# [382 rows x 13 columns]
# CPU times: user 2 s, sys: 21.7 ms, total: 2.03 s
# Wall time: 2.98 s

# %%
a
# Out:
# [{'IIiii': 'K8907',
#   'city': '台州',
#   'town': '埠头镇',
#   'county': '仙居县',
#   'StationName': '大陈村',
#   'fFy': '104.0',
#   'dFy': '352.0',
#   'RR': '82.0',
#   'Tx': '364.0',
#   'Tn': '228.0',
#   'VV': '9999.0',
#   'lat': '28.85028',
#   'lon': '120.5117'},
#  {'IIiii': 'K8654',
#   'city': '台州',
#   'town': '括苍镇',
#   'county': '临海市',
#   'StationName': '括苍山B',
#   'fFy': '96.0',
#   'dFy': '252.0',
#   'RR': '15.0',
#   'Tx': '229.0',
#   'Tn': '223.0',
#   'VV': '9999.0',
#   'lat': '28.78972',
#   'lon': '120.93333'},
#  {'IIiii': 'K8930',
#   'city': '台州',
#   'town': '田市镇',
#   'county': '仙居县',
#   'StationName': '台创园',
#   'fFy': '66.0',
#   'dFy': '54.0',
#   'RR': '0.0',
#   'Tx': '334.0',
#   'Tn': '334.0',
#   'VV': '9999.0',
#   'lat': '28.768',
#   'lon': '120.627'},
#  {'IIiii': '58645',
#   'city': '丽水',
#   'town': '水南街道',
#   'county': '松阳县',
#   'StationName': '松阳',
#   'fFy': '161.0',
#   'dFy': '299.0',
#   'RR': '3.0',
#   'Tx': '360.0',
#   'Tn': '249.0',
#   'VV': '5184.0',
#   'lat': '28.433333333333334',
#   'lon': '119.48333333333332'},
#  {'IIiii': '58562',
#   'city': '宁波',
#   'town': '石碶街道',
#   'county': '鄞州区',
#   'StationName': '鄞州',
#   'fFy': '236.0',
#   'dFy': '233.0',
#   'RR': '117.0',
#   'Tx': '362.0',
#   'Tn': '255.0',
#   'VV': '2472.0',
#   'lat': '29.8',
#   'lon': '121.5'},
#  {'IIiii': '58644',
#   'city': '丽水',
#   'town': '妙高街道',
#   'county': '遂昌县',
#   'StationName': '遂昌',
#   'fFy': '150.0',
#   'dFy': '337.0',
#   'RR': '320.0',
#   'Tx': '372.0',
#   'Tn': '244.0',
#   'VV': '12414.0',
#   'lat': '28.6',
#   'lon': '119.28333333333332'},
#  {'IIiii': 'K8273',
#   'city': '台州',
#   'town': '屿头乡',
#   'county': '黄岩区',
#   'StationName': '后岙',
#   'fFy': '127.0',
#   'dFy': '357.0',
#   'RR': '239.0',
#   'Tx': '346.0',
#   'Tn': '231.0',
#   'VV': '9999.0',
#   'lat': '28.66306',
#   'lon': '120.9097'},
#  {'IIiii': 'K8701',
#   'city': '台州',
#   'town': '白鹤镇',
#   'county': '天台县',
#   'StationName': '白鹤',
#   'fFy': '95.0',
#   'dFy': '358.0',
#   'RR': '323.0',
#   'Tx': '361.0',
#   'Tn': '240.0',
#   'VV': '9999.0',
#   'lat': '29.26778',
#   'lon': '120.9864'},
#  {'IIiii': 'K8708',
#   'city': '台州',
#   'town': '平桥镇',
#   'county': '天台县',
#   'StationName': '下王',
#   'fFy': '190.0',
#   'dFy': '282.0',
#   'RR': '205.0',
#   'Tx': '366.0',
#   'Tn': '247.0',
#   'VV': '9999.0',
#   'lat': '29.14472',
#   'lon': '120.8625'},
#  {'IIiii': 'K8746',
#   'city': '台州',
#   'town': '三州乡',
#   'county': '天台县',
#   'StationName': '三州',
#   'fFy': '176.0',
#   'dFy': '331.0',
#   'RR': '0.0',
#   'Tx': '318.0',
#   'Tn': '230.0',
#   'VV': '9999.0',
#   'lat': '29.22639',
#   'lon': '120.8475'},
#  {'IIiii': 'K8910',
#   'city': '台州',
#   'town': '湫山乡',
#   'county': '仙居县',
#   'StationName': '雅溪',
#   'fFy': '154.0',
#   'dFy': '356.0',
#   'RR': '10.0',
#   'Tx': '347.0',
#   'Tn': '213.0',
#   'VV': '9999.0',
#   'lat': '28.69806',
#   'lon': '120.3361'},
#  {'IIiii': '58544',
#   'city': '杭州',
#   'town': '新安江街道',
#   'county': '建德市',
#   'StationName': '建德',
#   'fFy': '166.0',
#   'dFy': '360.0',
#   'RR': '1.0',
#   'Tx': '356.0',
#   'Tn': '250.0',
#   'VV': '15739.0',
#   'lat': '29.48333333333333',
#   'lon': '119.26666666666668'},
#  {'IIiii': '58631',
#   'city': '衢州',
#   'town': '天马街道',
#   'county': '常山县',
#   'StationName': '常山',
#   'fFy': '202.0',
#   'dFy': '115.0',
#   'RR': '0.0',
#   'Tx': '362.0',
#   'Tn': '264.0',
#   'VV': '20000.0',
#   'lat': '28.9',
#   'lon': '118.5'},
#  {'IIiii': '58632',
#   'city': '衢州',
#   'town': '虎山街道',
#   'county': '江山市',
#   'StationName': '江山',
#   'fFy': '156.0',
#   'dFy': '135.0',
#   'RR': '0.0',
#   'Tx': '343.0',
#   'Tn': '268.0',
#   'VV': '20000.0',
#   'lat': '28.75',
#   'lon': '118.63333333333334'},
#  {'IIiii': '58633',
#   'city': '衢州',
#   'town': '浮石街道',
#   'county': '衢州衢江区',
#   'StationName': '衢州',
#   'fFy': '168.0',
#   'dFy': '75.0',
#   'RR': '0.0',
#   'Tx': '358.0',
#   'Tn': '261.0',
#   'VV': '20000.0',
#   'lat': '29.0',
#   'lon': '118.9'},
#  {'IIiii': '58642',
#   'city': '金华',
#   'town': '熟溪街道',
#   'county': '武义县',
#   'StationName': '武义',
#   'fFy': '215.0',
#   'dFy': '331.0',
#   'RR': '102.0',
#   'Tx': '356.0',
#   'Tn': '255.0',
#   'VV': '12426.0',
#   'lat': '28.883333333333333',
#   'lon': '119.8'},
#  {'IIiii': '58746',
#   'city': '温州',
#   'town': '罗阳镇',
#   'county': '泰顺县',
#   'StationName': '泰顺',
#   'fFy': '213.0',
#   'dFy': '352.0',
#   'RR': '185.0',
#   'Tx': '316.0',
#   'Tn': '232.0',
#   'VV': '16725.0',
#   'lat': '27.55',
#   'lon': '119.7'},
#  {'IIiii': '58444',
#   'city': '杭州',
#   'town': '临平街道',
#   'county': '临平区',
#   'StationName': '临平',
#   'fFy': '238.0',
#   'dFy': '129.0',
#   'RR': '215.0',
#   'Tx': '308.0',
#   'Tn': '248.0',
#   'VV': '1692.0',
#   'lat': '30.416666666666668',
#   'lon': '120.28333333333332'},
#  {'IIiii': '58471',
#   'city': '舟山',
#   'town': '马关镇',
#   'county': '嵊泗县',
#   'StationName': '白节',
#   'fFy': '365.0',
#   'dFy': '83.0',
#   'RR': '142.0',
#   'Tx': '283.0',
#   'Tn': '248.0',
#   'VV': '9999.0',
#   'lat': '30.616666666666667',
#   'lon': '122.41666666666669'},
#  {'IIiii': '58472',
#   'city': '舟山',
#   'town': '菜园镇',
#   'county': '嵊泗县',
#   'StationName': '嵊泗',
#   'fFy': '307.0',
#   'dFy': '85.0',
#   'RR': '500.0',
#   'Tx': '278.0',
#   'Tn': '247.0',
#   'VV': '2175.0',
#   'lat': '30.73333333333333',
#   'lon': '122.45'},
#  {'IIiii': '58473',
#   'city': '舟山',
#   'town': '嵊山镇',
#   'county': '嵊泗县',
#   'StationName': '嵊山',
#   'fFy': '328.0',
#   'dFy': '83.0',
#   'RR': '605.0',
#   'Tx': '279.0',
#   'Tn': '247.0',
#   'VV': '1184.0',
#   'lat': '30.73333333333333',
#   'lon': '122.81666666666666'},
#  {'IIiii': '58572',
#   'city': '舟山',
#   'town': '白沙管委会',
#   'county': '普陀区',
#   'StationName': '白沙',
#   'fFy': '347.0',
#   'dFy': '108.0',
#   'RR': '557.0',
#   'Tx': '279.0',
#   'Tn': '252.0',
#   'VV': '1599.0',
#   'lat': '29.933333333333334',
#   'lon': '122.45'},
#  {'IIiii': '58751',
#   'city': '温州',
#   'town': '昆阳镇',
#   'county': '平阳县',
#   'StationName': '平阳',
#   'fFy': '293.0',
#   'dFy': '359.0',
#   'RR': '571.0',
#   'Tx': '261.0',
#   'Tn': '241.0',
#   'VV': '136.0',
#   'lat': '27.666666666666668',
#   'lon': '120.56666666666666'},
#  {'IIiii': '58764',
#   'city': '温州',
#   'town': '南麂镇',
#   'county': '平阳县',
#   'StationName': '南麂',
#   'fFy': '399.0',
#   'dFy': '359.0',
#   'RR': '1511.0',
#   'Tx': '281.0',
#   'Tn': '248.0',
#   'VV': '638.0',
#   'lat': '27.466666666666665',
#   'lon': '121.08333333333331'},
#  {'IIiii': '58765',
#   'city': '温州',
#   'town': '北麂乡',
#   'county': '瑞安市',
#   'StationName': '北麂',
#   'fFy': '456.0',
#   'dFy': '357.0',
#   'RR': '1209.0',
#   'Tx': '287.0',
#   'Tn': '248.0',
#   'VV': '645.0',
#   'lat': '27.633333333333333',
#   'lon': '121.2'},
#  {'IIiii': 'K8526',
#   'city': '台州',
#   'town': 'None',
#   'county': '玉环市',
#   'StationName': '玉环轮渡',
#   'fFy': '347.0',
#   'dFy': '88.0',
#   'RR': '0.0',
#   'Tx': '297.0',
#   'Tn': '262.0',
#   'VV': '9999.0',
#   'lat': '28.1333',
#   'lon': '121.1333'},
#  {'IIiii': 'K8629',
#   'city': '台州',
#   'town': '上盘镇',
#   'county': '临海市',
#   'StationName': '雀儿岙',
#   'fFy': '315.0',
#   'dFy': '47.0',
#   'RR': '405.0',
#   'Tx': '285.0',
#   'Tn': '259.0',
#   'VV': '781.0',
#   'lat': '28.80972',
#   'lon': '121.8475'},
#  {'IIiii': 'K8720',
#   'city': '台州',
#   'town': '平桥镇',
#   'county': '天台县',
#   'StationName': '屯桥',
#   'fFy': '239.0',
#   'dFy': '359.0',
#   'RR': '438.0',
#   'Tx': '286.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '29.20111',
#   'lon': '120.8997'},
#  {'IIiii': 'K8730',
#   'city': '台州',
#   'town': '龙溪乡',
#   'county': '天台县',
#   'StationName': '天柱林场',
#   'fFy': '266.0',
#   'dFy': '358.0',
#   'RR': '1272.0',
#   'Tx': '224.0',
#   'Tn': '208.0',
#   'VV': '9999.0',
#   'lat': '28.97583',
#   'lon': '120.8189'},
#  {'IIiii': 'K8948',
#   'city': '台州',
#   'town': '湫山乡',
#   'county': '仙居县',
#   'StationName': '上蓄能',
#   'fFy': '160.0',
#   'dFy': '80.0',
#   'RR': '760.0',
#   'Tx': '239.0',
#   'Tn': '219.0',
#   'VV': '9999.0',
#   'lat': '28.64528',
#   'lon': '120.4169'},
#  {'IIiii': '58443',
#   'city': '湖州',
#   'town': '龙山街道',
#   'county': '长兴县',
#   'StationName': '长兴',
#   'fFy': '212.0',
#   'dFy': '68.0',
#   'RR': '1800.0',
#   'Tx': '271.0',
#   'Tn': '257.0',
#   'VV': '1842.0',
#   'lat': '31.016666666666666',
#   'lon': '119.9'},
#  {'IIiii': '58446',
#   'city': '湖州',
#   'town': '昌硕街道',
#   'county': '安吉县',
#   'StationName': '安吉',
#   'fFy': '161.0',
#   'dFy': '359.0',
#   'RR': '1418.0',
#   'Tx': '267.0',
#   'Tn': '250.0',
#   'VV': '2609.0',
#   'lat': '30.633333333333333',
#   'lon': '119.7'},
#  {'IIiii': '58448',
#   'city': '杭州',
#   'town': '锦南街道',
#   'county': '临安区',
#   'StationName': '临安',
#   'fFy': '256.0',
#   'dFy': '326.0',
#   'RR': '1112.0',
#   'Tx': '264.0',
#   'Tn': '246.0',
#   'VV': '1858.0',
#   'lat': '30.3',
#   'lon': '119.73333333333332'},
#  {'IIiii': '58449',
#   'city': '杭州',
#   'town': '富春街道',
#   'county': '富阳区',
#   'StationName': '富阳',
#   'fFy': '218.0',
#   'dFy': '360.0',
#   'RR': '1100.0',
#   'Tx': '270.0',
#   'Tn': '252.0',
#   'VV': '3389.0',
#   'lat': '30.05',
#   'lon': '119.95'},
#  {'IIiii': '58450',
#   'city': '湖州',
#   'town': '龙溪街道',
#   'county': '湖州市',
#   'StationName': '湖州',
#   'fFy': '187.0',
#   'dFy': '86.0',
#   'RR': '1562.0',
#   'Tx': '272.0',
#   'Tn': '259.0',
#   'VV': '2046.0',
#   'lat': '30.85',
#   'lon': '120.08333333333331'},
#  {'IIiii': '58453',
#   'city': '绍兴',
#   'town': '柯桥街道',
#   'county': '柯桥区',
#   'StationName': '柯桥',
#   'fFy': '218.0',
#   'dFy': '214.0',
#   'RR': '1098.0',
#   'Tx': '279.0',
#   'Tn': '262.0',
#   'VV': '2367.0',
#   'lat': '30.066666666666663',
#   'lon': '120.5'},
#  {'IIiii': '58454',
#   'city': '湖州',
#   'town': '舞阳街道',
#   'county': '德清县',
#   'StationName': '德清',
#   'fFy': '209.0',
#   'dFy': '347.0',
#   'RR': '1111.0',
#   'Tx': '264.0',
#   'Tn': '246.0',
#   'VV': '554.0',
#   'lat': '30.53333333333333',
#   'lon': '119.98333333333332'},
#  {'IIiii': '58457',
#   'city': '杭州',
#   'town': '紫阳街道',
#   'county': '杭州市',
#   'StationName': '杭州',
#   'fFy': '197.0',
#   'dFy': '360.0',
#   'RR': '1333.0',
#   'Tx': '275.0',
#   'Tn': '254.0',
#   'VV': '2821.0',
#   'lat': '30.23333333333333',
#   'lon': '120.16666666666669'},
#  {'IIiii': '58459',
#   'city': '杭州',
#   'town': '北干街道',
#   'county': '萧山区',
#   'StationName': '萧山',
#   'fFy': '245.0',
#   'dFy': '253.0',
#   'RR': '1237.0',
#   'Tx': '267.0',
#   'Tn': '248.0',
#   'VV': '1198.0',
#   'lat': '30.183333333333334',
#   'lon': '120.28333333333332'},
#  {'IIiii': '58466',
#   'city': '舟山',
#   'town': '洋山镇',
#   'county': '嵊泗县',
#   'StationName': '大洋山',
#   'fFy': '294.0',
#   'dFy': '183.0',
#   'RR': '617.0',
#   'Tx': '279.0',
#   'Tn': '265.0',
#   'VV': '1323.0',
#   'lat': '30.6',
#   'lon': '122.08333333333331'},
#  {'IIiii': '58467',
#   'city': '宁波',
#   'town': '白沙路街道',
#   'county': '慈溪市',
#   'StationName': '慈溪',
#   'fFy': '219.0',
#   'dFy': '160.0',
#   'RR': '1699.0',
#   'Tx': '272.0',
#   'Tn': '259.0',
#   'VV': '1607.0',
#   'lat': '30.2',
#   'lon': '121.3'},
#  {'IIiii': '58468',
#   'city': '宁波',
#   'town': '兰江街道',
#   'county': '余姚市',
#   'StationName': '余姚',
#   'fFy': '282.0',
#   'dFy': '117.0',
#   'RR': '1337.0',
#   'Tx': '271.0',
#   'Tn': '253.0',
#   'VV': '3193.0',
#   'lat': '30.05',
#   'lon': '121.16666666666669'},
#  {'IIiii': '58469',
#   'city': '舟山',
#   'town': '大鱼乡',
#   'county': '岱山县',
#   'StationName': '大渔山',
#   'fFy': '330.0',
#   'dFy': '143.0',
#   'RR': '1138.0',
#   'Tx': '279.0',
#   'Tn': '261.0',
#   'VV': '1249.0',
#   'lat': '30.316666666666663',
#   'lon': '121.95'},
#  {'IIiii': '58476',
#   'city': '舟山',
#   'town': '东沙镇',
#   'county': '岱山县',
#   'StationName': '次蓬山',
#   'fFy': '382.0',
#   'dFy': '175.0',
#   'RR': '723.0',
#   'Tx': '276.0',
#   'Tn': '249.0',
#   'VV': '9999.0',
#   'lat': '30.35',
#   'lon': '122.18333333333334'},
#  {'IIiii': '58477',
#   'city': '舟山',
#   'town': '昌国街道',
#   'county': '定海区',
#   'StationName': '定海',
#   'fFy': '257.0',
#   'dFy': '136.0',
#   'RR': '1768.0',
#   'Tx': '279.0',
#   'Tn': '255.0',
#   'VV': '1095.0',
#   'lat': '30.03333333333333',
#   'lon': '122.1'},
#  {'IIiii': '58478',
#   'city': '舟山',
#   'town': 'None',
#   'county': '岱山县',
#   'StationName': '灰鳖山',
#   'fFy': '338.0',
#   'dFy': '171.0',
#   'RR': '749.0',
#   'Tx': '277.0',
#   'Tn': '256.0',
#   'VV': '338.0',
#   'lat': '30.25',
#   'lon': '122.08333333333331'},
#  {'IIiii': '58484',
#   'city': '舟山',
#   'town': '高亭镇',
#   'county': '岱山县',
#   'StationName': '岱山',
#   'fFy': '266.0',
#   'dFy': '142.0',
#   'RR': '1795.0',
#   'Tx': '276.0',
#   'Tn': '251.0',
#   'VV': '1145.0',
#   'lat': '30.25',
#   'lon': '122.2'},
#  {'IIiii': '58487',
#   'city': '舟山',
#   'town': '东极镇',
#   'county': '普陀区',
#   'StationName': '东极',
#   'fFy': '379.0',
#   'dFy': '158.0',
#   'RR': '531.0',
#   'Tx': '277.0',
#   'Tn': '263.0',
#   'VV': '9999.0',
#   'lat': '30.183333333333334',
#   'lon': '122.68333333333334'},
#  {'IIiii': '58537',
#   'city': '衢州',
#   'town': '芹阳办事处',
#   'county': '开化县',
#   'StationName': '开化',
#   'fFy': '141.0',
#   'dFy': '344.0',
#   'RR': '272.0',
#   'Tx': '289.0',
#   'Tn': '244.0',
#   'VV': '4020.0',
#   'lat': '29.133333333333333',
#   'lon': '118.4'},
#  {'IIiii': '58542',
#   'city': '杭州',
#   'town': '桐君街道',
#   'county': '桐庐县',
#   'StationName': '桐庐',
#   'fFy': '185.0',
#   'dFy': '357.0',
#   'RR': '825.0',
#   'Tx': '277.0',
#   'Tn': '256.0',
#   'VV': '3365.0',
#   'lat': '29.816666666666663',
#   'lon': '119.68333333333334'},
#  {'IIiii': '58543',
#   'city': '杭州',
#   'town': '千岛湖镇',
#   'county': '淳安县',
#   'StationName': '淳安',
#   'fFy': '170.0',
#   'dFy': '329.0',
#   'RR': '975.0',
#   'Tx': '266.0',
#   'Tn': '247.0',
#   'VV': '2999.0',
#   'lat': '29.616666666666667',
#   'lon': '119.01666666666668'},
#  {'IIiii': '58546',
#   'city': '金华',
#   'town': '浦阳街道',
#   'county': '浦江县',
#   'StationName': '浦江',
#   'fFy': '174.0',
#   'dFy': '360.0',
#   'RR': '388.0',
#   'Tx': '276.0',
#   'Tn': '257.0',
#   'VV': '3842.0',
#   'lat': '29.466666666666665',
#   'lon': '119.88333333333334'},
#  {'IIiii': '58547',
#   'city': '衢州',
#   'town': '东华街道',
#   'county': '龙游县',
#   'StationName': '龙游',
#   'fFy': '180.0',
#   'dFy': '324.0',
#   'RR': '1892.0',
#   'Tx': '277.0',
#   'Tn': '249.0',
#   'VV': '3791.0',
#   'lat': '29.03333333333333',
#   'lon': '119.18333333333334'},
#  {'IIiii': '58548',
#   'city': '金华',
#   'town': '云山街道',
#   'county': '兰溪市',
#   'StationName': '兰溪',
#   'fFy': '152.0',
#   'dFy': '358.0',
#   'RR': '620.0',
#   'Tx': '274.0',
#   'Tn': '255.0',
#   'VV': '3257.0',
#   'lat': '29.216666666666665',
#   'lon': '119.46666666666668'},
#  {'IIiii': '58549',
#   'city': '金华',
#   'town': '城中街道',
#   'county': '金华市',
#   'StationName': '金华',
#   'fFy': '176.0',
#   'dFy': '275.0',
#   'RR': '512.0',
#   'Tx': '283.0',
#   'Tn': '254.0',
#   'VV': '4237.0',
#   'lat': '29.116666666666667',
#   'lon': '119.65'},
#  {'IIiii': '58550',
#   'city': '绍兴',
#   'town': '暨阳街道',
#   'county': '诸暨市',
#   'StationName': '诸暨',
#   'fFy': '186.0',
#   'dFy': '360.0',
#   'RR': '795.0',
#   'Tx': '275.0',
#   'Tn': '253.0',
#   'VV': '2414.0',
#   'lat': '29.7',
#   'lon': '120.25'},
#  {'IIiii': '58553',
#   'city': '绍兴',
#   'town': '崧厦镇',
#   'county': '上虞区',
#   'StationName': '上虞',
#   'fFy': '212.0',
#   'dFy': '164.0',
#   'RR': '827.0',
#   'Tx': '276.0',
#   'Tn': '261.0',
#   'VV': '3872.0',
#   'lat': '30.05',
#   'lon': '120.81666666666666'},
#  {'IIiii': '58554',
#   'city': '绍兴',
#   'town': '盖北镇',
#   'county': '上虞区',
#   'StationName': '盖北',
#   'fFy': '210.0',
#   'dFy': '176.0',
#   'RR': '959.0',
#   'Tx': '270.0',
#   'Tn': '260.0',
#   'VV': '794.0',
#   'lat': '30.166666666666668',
#   'lon': '120.88333333333334'},
#  {'IIiii': '58555',
#   'city': '绍兴',
#   'town': '七星街道',
#   'county': '新昌县',
#   'StationName': '新昌',
#   'fFy': '179.0',
#   'dFy': '348.0',
#   'RR': '918.0',
#   'Tx': '270.0',
#   'Tn': '250.0',
#   'VV': '5463.0',
#   'lat': '29.516666666666666',
#   'lon': '120.88333333333334'},
#  {'IIiii': '58556',
#   'city': '绍兴',
#   'town': '剡湖街道',
#   'county': '嵊州市',
#   'StationName': '嵊州',
#   'fFy': '183.0',
#   'dFy': '182.0',
#   'RR': '803.0',
#   'Tx': '263.0',
#   'Tn': '252.0',
#   'VV': '2799.0',
#   'lat': '29.6',
#   'lon': '120.81666666666666'},
#  {'IIiii': '58557',
#   'city': '金华',
#   'town': '福田街道',
#   'county': '义乌市',
#   'StationName': '义乌',
#   'fFy': '208.0',
#   'dFy': '359.0',
#   'RR': '541.0',
#   'Tx': '272.0',
#   'Tn': '255.0',
#   'VV': '2173.0',
#   'lat': '29.316666666666663',
#   'lon': '120.06666666666666'},
#  {'IIiii': '58559',
#   'city': '台州',
#   'town': '始丰街道',
#   'county': '天台县',
#   'StationName': '天台',
#   'fFy': '214.0',
#   'dFy': '338.0',
#   'RR': '1712.0',
#   'Tx': '269.0',
#   'Tn': '250.0',
#   'VV': '2570.0',
#   'lat': '29.15278',
#   'lon': '120.97056'},
#  {'IIiii': '58560',
#   'city': '金华',
#   'town': '安文街道',
#   'county': '磐安县',
#   'StationName': '磐安',
#   'fFy': '220.0',
#   'dFy': '347.0',
#   'RR': '1894.0',
#   'Tx': '253.0',
#   'Tn': '246.0',
#   'VV': '4070.0',
#   'lat': '29.05',
#   'lon': '120.43333333333334'},
#  {'IIiii': '58561',
#   'city': '宁波',
#   'town': '贵驷街道',
#   'county': '镇海区',
#   'StationName': '镇海',
#   'fFy': '204.0',
#   'dFy': '156.0',
#   'RR': '1873.0',
#   'Tx': '275.0',
#   'Tn': '260.0',
#   'VV': '2168.0',
#   'lat': '29.98333333333333',
#   'lon': '121.6'},
#  {'IIiii': '58563',
#   'city': '宁波',
#   'town': '大碶街道',
#   'county': '北仑区',
#   'StationName': '北仑',
#   'fFy': '242.0',
#   'dFy': '150.0',
#   'RR': '2910.0',
#   'Tx': '278.0',
#   'Tn': '256.0',
#   'VV': '1512.0',
#   'lat': '29.883333333333333',
#   'lon': '121.83333333333331'},
#  {'IIiii': '58564',
#   'city': '宁波',
#   'town': 'None',
#   'county': '宁海县',
#   'StationName': '白石山',
#   'fFy': '351.0',
#   'dFy': '166.0',
#   'RR': '1148.0',
#   'Tx': '284.0',
#   'Tn': '257.0',
#   'VV': '845.0',
#   'lat': '29.266666666666666',
#   'lon': '121.5'},
#  {'IIiii': '58565',
#   'city': '宁波',
#   'town': '锦屏街道',
#   'county': '奉化区',
#   'StationName': '奉化',
#   'fFy': '228.0',
#   'dFy': '170.0',
#   'RR': '1249.0',
#   'Tx': '265.0',
#   'Tn': '257.0',
#   'VV': '2693.0',
#   'lat': '29.7',
#   'lon': '121.38333333333334'},
#  {'IIiii': '58566',
#   'city': '宁波',
#   'town': '东陈乡',
#   'county': '象山县',
#   'StationName': '象山',
#   'fFy': '302.0',
#   'dFy': '226.0',
#   'RR': '1245.0',
#   'Tx': '287.0',
#   'Tn': '258.0',
#   'VV': '1011.0',
#   'lat': '29.466666666666665',
#   'lon': '121.88333333333334'},
#  {'IIiii': '58567',
#   'city': '宁波',
#   'town': '跃龙街道',
#   'county': '宁海县',
#   'StationName': '宁海',
#   'fFy': '254.0',
#   'dFy': '184.0',
#   'RR': '2174.0',
#   'Tx': '278.0',
#   'Tn': '257.0',
#   'VV': '1173.0',
#   'lat': '29.316666666666663',
#   'lon': '121.43333333333334'},
#  {'IIiii': '58568',
#   'city': '台州',
#   'town': '海游街道',
#   'county': '三门县',
#   'StationName': '三门',
#   'fFy': '264.0',
#   'dFy': '201.0',
#   'RR': '2043.0',
#   'Tx': '283.0',
#   'Tn': '260.0',
#   'VV': '2184.0',
#   'lat': '29.12278',
#   'lon': '121.38333'},
#  {'IIiii': '58569',
#   'city': '宁波',
#   'town': '石浦镇',
#   'county': '象山县',
#   'StationName': '石浦',
#   'fFy': '411.0',
#   'dFy': '213.0',
#   'RR': '777.0',
#   'Tx': '287.0',
#   'Tn': '249.0',
#   'VV': '948.0',
#   'lat': '29.2',
#   'lon': '121.95'},
#  {'IIiii': '58570',
#   'city': '舟山',
#   'town': '沈家门街道',
#   'county': '普陀区',
#   'StationName': '普陀',
#   'fFy': '312.0',
#   'dFy': '162.0',
#   'RR': '1321.0',
#   'Tx': '277.0',
#   'Tn': '252.0',
#   'VV': '1463.0',
#   'lat': '29.95',
#   'lon': '122.3'},
#  {'IIiii': '58571',
#   'city': '舟山',
#   'town': '蚂蚁管委会',
#   'county': '普陀区',
#   'StationName': '蚂蚁',
#   'fFy': '364.0',
#   'dFy': '182.0',
#   'RR': '806.0',
#   'Tx': '250.0',
#   'Tn': '233.0',
#   'VV': '9999.0',
#   'lat': '29.866666666666667',
#   'lon': '122.26666666666668'},
#  {'IIiii': '58573',
#   'city': '舟山',
#   'town': 'None',
#   'county': '舟山浮标',
#   'StationName': '舟山浮标1',
#   'fFy': '316.0',
#   'dFy': '254.0',
#   'RR': '969.0',
#   'Tx': '286.0',
#   'Tn': '255.0',
#   'VV': '1082.0',
#   'lat': '29.75',
#   'lon': '122.75'},
#  {'IIiii': '58574',
#   'city': '宁波',
#   'town': 'None',
#   'county': '象山县',
#   'StationName': '小东屿',
#   'fFy': '340.0',
#   'dFy': '187.0',
#   'RR': '1330.0',
#   'Tx': '278.0',
#   'Tn': '254.0',
#   'VV': '212.0',
#   'lat': '29.633333333333333',
#   'lon': '122.01666666666668'},
#  {'IIiii': '58643',
#   'city': '金华',
#   'town': '江南街道',
#   'county': '永康市',
#   'StationName': '永康',
#   'fFy': '152.0',
#   'dFy': '353.0',
#   'RR': '661.0',
#   'Tx': '282.0',
#   'Tn': '254.0',
#   'VV': '2105.0',
#   'lat': '28.9',
#   'lon': '120.03333333333332'},
#  {'IIiii': '58648',
#   'city': '丽水',
#   'town': '红星街道',
#   'county': '景宁县',
#   'StationName': '景宁',
#   'fFy': '137.0',
#   'dFy': '233.0',
#   'RR': '592.0',
#   'Tx': '309.0',
#   'Tn': '240.0',
#   'VV': '4137.0',
#   'lat': '27.99195',
#   'lon': '119.635'},
#  {'IIiii': '58652',
#   'city': '台州',
#   'town': '安洲街道',
#   'county': '仙居县',
#   'StationName': '仙居',
#   'fFy': '254.0',
#   'dFy': '360.0',
#   'RR': '1482.0',
#   'Tx': '274.0',
#   'Tn': '254.0',
#   'VV': '3514.0',
#   'lat': '28.86722',
#   'lon': '120.71889'},
#  {'IIiii': '58653',
#   'city': '台州',
#   'town': '括苍镇',
#   'county': '临海市',
#   'StationName': '括苍山',
#   'fFy': '347.0',
#   'dFy': '356.0',
#   'RR': '5523.0',
#   'Tx': '203.0',
#   'Tn': '196.0',
#   'VV': '9999.0',
#   'lat': '28.80972',
#   'lon': '120.9222'},
#  {'IIiii': '58654',
#   'city': '丽水',
#   'town': '五云街道',
#   'county': '缙云县',
#   'StationName': '缙云',
#   'fFy': '154.0',
#   'dFy': '336.0',
#   'RR': '799.0',
#   'Tx': '283.0',
#   'Tn': '252.0',
#   'VV': '2694.0',
#   'lat': '28.666666666666668',
#   'lon': '120.08333333333331'},
#  {'IIiii': '58656',
#   'city': '温州',
#   'town': '盐盆街道',
#   'county': '乐清市',
#   'StationName': '乐清',
#   'fFy': '350.0',
#   'dFy': '351.0',
#   'RR': '900.0',
#   'Tx': '295.0',
#   'Tn': '253.0',
#   'VV': '2783.0',
#   'lat': '28.066666666666663',
#   'lon': '120.96666666666668'},
#  {'IIiii': '58657',
#   'city': '丽水',
#   'town': '鹤城街道',
#   'county': '青田县',
#   'StationName': '青田',
#   'fFy': '179.0',
#   'dFy': '315.0',
#   'RR': '279.0',
#   'Tx': '301.0',
#   'Tn': '260.0',
#   'VV': '6013.0',
#   'lat': '28.15',
#   'lon': '120.28333333333332'},
#  {'IIiii': '58658',
#   'city': '温州',
#   'town': '东城街道',
#   'county': '永嘉县',
#   'StationName': '永嘉',
#   'fFy': '272.0',
#   'dFy': '337.0',
#   'RR': '955.0',
#   'Tx': '280.0',
#   'Tn': '258.0',
#   'VV': '3903.0',
#   'lat': '28.15',
#   'lon': '120.68333333333334'},
#  {'IIiii': '58659',
#   'city': '温州',
#   'town': '五马街道',
#   'county': '温州鹿城',
#   'StationName': '温州',
#   'fFy': '126.0',
#   'dFy': '353.0',
#   'RR': '427.0',
#   'Tx': '288.0',
#   'Tn': '251.0',
#   'VV': '2338.0',
#   'lat': '28.03333333333333',
#   'lon': '120.65'},
#  {'IIiii': '58660',
#   'city': '台州',
#   'town': '大洋街道',
#   'county': '临海市',
#   'StationName': '临海',
#   'fFy': '246.0',
#   'dFy': '194.0',
#   'RR': '2206.0',
#   'Tx': '277.0',
#   'Tn': '260.0',
#   'VV': '2677.0',
#   'lat': '28.87389',
#   'lon': '121.19278'},
#  {'IIiii': '58661',
#   'city': '台州',
#   'town': '海门街道',
#   'county': '椒江区',
#   'StationName': '椒江口',
#   'fFy': '335.0',
#   'dFy': '227.0',
#   'RR': '1024.0',
#   'Tx': '289.0',
#   'Tn': '257.0',
#   'VV': '802.0',
#   'lat': '28.6625',
#   'lon': '121.5108'},
#  {'IIiii': '58662',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '牛山',
#   'fFy': '332.0',
#   'dFy': '190.0',
#   'RR': '527.0',
#   'Tx': '275.0',
#   'Tn': '254.0',
#   'VV': '1832.0',
#   'lat': '29.0131',
#   'lon': '121.7056'},
#  {'IIiii': '58663',
#   'city': '台州',
#   'town': '上盘镇',
#   'county': '临海市',
#   'StationName': '东矶',
#   'fFy': '400.0',
#   'dFy': '180.0',
#   'RR': '396.0',
#   'Tx': '280.0',
#   'Tn': '249.0',
#   'VV': '1143.0',
#   'lat': '28.71889',
#   'lon': '121.9156'},
#  {'IIiii': '58664',
#   'city': '台州',
#   'town': '太平街道',
#   'county': '温岭市',
#   'StationName': '温岭',
#   'fFy': '414.0',
#   'dFy': '214.0',
#   'RR': '2186.0',
#   'Tx': '303.0',
#   'Tn': '252.0',
#   'VV': '1477.0',
#   'lat': '28.37278',
#   'lon': '121.35889'},
#  {'IIiii': '58665',
#   'city': '台州',
#   'town': '洪家街道',
#   'county': '椒江区',
#   'StationName': '洪家',
#   'fFy': '317.0',
#   'dFy': '216.0',
#   'RR': '1010.0',
#   'Tx': '295.0',
#   'Tn': '260.0',
#   'VV': '1766.0',
#   'lat': '28.61806',
#   'lon': '121.41639'},
#  {'IIiii': '58666',
#   'city': '台州',
#   'town': '大陈镇',
#   'county': '椒江区',
#   'StationName': '大陈',
#   'fFy': '527.0',
#   'dFy': '209.0',
#   'RR': '956.0',
#   'Tx': '280.0',
#   'Tn': '250.0',
#   'VV': '230.0',
#   'lat': '28.446',
#   'lon': '121.90333'},
#  {'IIiii': '58667',
#   'city': '台州',
#   'town': '坎门街道',
#   'county': '玉环市',
#   'StationName': '坎门',
#   'fFy': '437.0',
#   'dFy': '340.0',
#   'RR': '1706.0',
#   'Tx': '295.0',
#   'Tn': '249.0',
#   'VV': '970.0',
#   'lat': '28.0775',
#   'lon': '121.27083'},
#  {'IIiii': '58668',
#   'city': '台州',
#   'town': '鸡山乡',
#   'county': '玉环市',
#   'StationName': '披山',
#   'fFy': '557.0',
#   'dFy': '279.0',
#   'RR': '1068.0',
#   'Tx': '281.0',
#   'Tn': '250.0',
#   'VV': '326.0',
#   'lat': '28.09583',
#   'lon': '121.52'},
#  {'IIiii': '58669',
#   'city': '台州',
#   'town': '石塘镇',
#   'county': '温岭市',
#   'StationName': '石塘',
#   'fFy': '555.0',
#   'dFy': '231.0',
#   'RR': '751.0',
#   'Tx': '286.0',
#   'Tn': '248.0',
#   'VV': '395.0',
#   'lat': '28.260317',
#   'lon': '121.616252'},
#  {'IIiii': '58742',
#   'city': '丽水',
#   'town': '凤凰山街道',
#   'county': '云和县',
#   'StationName': '云和',
#   'fFy': '162.0',
#   'dFy': '327.0',
#   'RR': '185.0',
#   'Tx': '318.0',
#   'Tn': '252.0',
#   'VV': '7402.0',
#   'lat': '28.116666666666667',
#   'lon': '119.55'},
#  {'IIiii': '58745',
#   'city': '丽水',
#   'town': '濛洲街道',
#   'county': '庆元县',
#   'StationName': '庆元',
#   'fFy': '152.0',
#   'dFy': '287.0',
#   'RR': '236.0',
#   'Tx': '265.0',
#   'Tn': '241.0',
#   'VV': '5054.0',
#   'lat': '27.616666666666667',
#   'lon': '119.08333333333331'},
#  {'IIiii': '58750',
#   'city': '温州',
#   'town': '大峃镇',
#   'county': '文成县',
#   'StationName': '文成',
#   'fFy': '170.0',
#   'dFy': '355.0',
#   'RR': '132.0',
#   'Tx': '324.0',
#   'Tn': '268.0',
#   'VV': '9441.0',
#   'lat': '27.78333333333333',
#   'lon': '120.08333333333331'},
#  {'IIiii': '58752',
#   'city': '温州',
#   'town': '安阳街道',
#   'county': '瑞安市',
#   'StationName': '瑞安',
#   'fFy': '213.0',
#   'dFy': '302.0',
#   'RR': '161.0',
#   'Tx': '316.0',
#   'Tn': '261.0',
#   'VV': '7225.0',
#   'lat': '27.78333333333333',
#   'lon': '120.65'},
#  {'IIiii': '58753',
#   'city': '温州',
#   'town': '海安镇',
#   'county': '瑞安市',
#   'StationName': '海安',
#   'fFy': '195.0',
#   'dFy': '321.0',
#   'RR': '216.0',
#   'Tx': '304.0',
#   'Tn': '256.0',
#   'VV': '1731.0',
#   'lat': '27.8',
#   'lon': '120.76666666666668'},
#  {'IIiii': '58755',
#   'city': '温州',
#   'town': '灵溪镇',
#   'county': '苍南县',
#   'StationName': '苍南',
#   'fFy': '228.0',
#   'dFy': '289.0',
#   'RR': '186.0',
#   'Tx': '308.0',
#   'Tn': '253.0',
#   'VV': '5814.0',
#   'lat': '27.5',
#   'lon': '120.38333333333334'},
#  {'IIiii': '58758',
#   'city': '温州',
#   'town': '霞关镇',
#   'county': '苍南县',
#   'StationName': '霞关',
#   'fFy': '266.0',
#   'dFy': '275.0',
#   'RR': '147.0',
#   'Tx': '307.0',
#   'Tn': '259.0',
#   'VV': '6451.0',
#   'lat': '27.166666666666668',
#   'lon': '120.48333333333332'},
#  {'IIiii': '58760',
#   'city': '温州',
#   'town': '东屏街道',
#   'county': '洞头区',
#   'StationName': '洞头',
#   'fFy': '410.0',
#   'dFy': '343.0',
#   'RR': '1144.0',
#   'Tx': '296.0',
#   'Tn': '255.0',
#   'VV': '1896.0',
#   'lat': '27.83333333333333',
#   'lon': '121.15'},
#  {'IIiii': '58761',
#   'city': '温州',
#   'town': '鹿西乡',
#   'county': '洞头区',
#   'StationName': '鹿西',
#   'fFy': '508.0',
#   'dFy': '339.0',
#   'RR': '1161.0',
#   'Tx': '289.0',
#   'Tn': '249.0',
#   'VV': '793.0',
#   'lat': '28.0',
#   'lon': '121.23333333333332'},
#  {'IIiii': '58762',
#   'city': '温州',
#   'town': '东屏镇',
#   'county': '洞头区',
#   'StationName': '大瞿',
#   'fFy': '405.0',
#   'dFy': '284.0',
#   'RR': '547.0',
#   'Tx': '288.0',
#   'Tn': '252.0',
#   'VV': '813.0',
#   'lat': '27.78333333333333',
#   'lon': '121.08333333333331'},
#  {'IIiii': '58763',
#   'city': '温州',
#   'town': '南岳镇',
#   'county': '乐清市',
#   'StationName': '南岳',
#   'fFy': '403.0',
#   'dFy': '359.0',
#   'RR': '553.0',
#   'Tx': '289.0',
#   'Tn': '250.0',
#   'VV': '1108.0',
#   'lat': '28.183333333333334',
#   'lon': '121.1'},
#  {'IIiii': '58768',
#   'city': '温州',
#   'town': 'None',
#   'county': '温州浮标',
#   'StationName': '温州浮标1',
#   'fFy': '415.0',
#   'dFy': '359.0',
#   'RR': '494.0',
#   'Tx': '295.0',
#   'Tn': '253.0',
#   'VV': '377.0',
#   'lat': '27.55',
#   'lon': '121.4'},
#  {'IIiii': 'K8001',
#   'city': '台州',
#   'town': '白云街道',
#   'county': '椒江区',
#   'StationName': '赤龙',
#   'fFy': '265.0',
#   'dFy': '209.0',
#   'RR': '890.0',
#   'Tx': '299.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '28.65472',
#   'lon': '121.4189'},
#  {'IIiii': 'K8002',
#   'city': '台州',
#   'town': '上盘镇',
#   'county': '临海市',
#   'StationName': '东矶B',
#   'fFy': '415.0',
#   'dFy': '212.0',
#   'RR': '371.0',
#   'Tx': '279.0',
#   'Tn': '249.0',
#   'VV': '30000.0',
#   'lat': '28.71889',
#   'lon': '121.9156'},
#  {'IIiii': 'K8003',
#   'city': '台州',
#   'town': '葭沚街道',
#   'county': '椒江区',
#   'StationName': '绿心',
#   'fFy': '418.0',
#   'dFy': '237.0',
#   'RR': '671.0',
#   'Tx': '265.0',
#   'Tn': '241.0',
#   'VV': '9999.0',
#   'lat': '28.638986',
#   'lon': '121.3521'},
#  {'IIiii': 'K8101',
#   'city': '台州',
#   'town': '海门街道',
#   'county': '椒江区',
#   'StationName': '东方红',
#   'fFy': '323.0',
#   'dFy': '232.0',
#   'RR': '911.0',
#   'Tx': '297.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.67805',
#   'lon': '121.4467'},
#  {'IIiii': 'K8103',
#   'city': '台州',
#   'town': '前所街道',
#   'county': '椒江区',
#   'StationName': '涛江闸',
#   'fFy': '306.0',
#   'dFy': '214.0',
#   'RR': '1114.0',
#   'Tx': '291.0',
#   'Tn': '254.0',
#   'VV': '9999.0',
#   'lat': '28.69667',
#   'lon': '121.4897'},
#  {'IIiii': 'K8104',
#   'city': '台州',
#   'town': '章安街道',
#   'county': '椒江区',
#   'StationName': '马峙',
#   'fFy': '282.0',
#   'dFy': '358.0',
#   'RR': '1335.0',
#   'Tx': '299.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '28.75389',
#   'lon': '121.4047'},
#  {'IIiii': 'K8106',
#   'city': '台州',
#   'town': '章安街道',
#   'county': '椒江区',
#   'StationName': '大桥',
#   'fFy': '281.0',
#   'dFy': '212.0',
#   'RR': '1372.0',
#   'Tx': '287.0',
#   'Tn': '254.0',
#   'VV': '1328.0',
#   'lat': '28.70806',
#   'lon': '121.3967'},
#  {'IIiii': 'K8107',
#   'city': '台州',
#   'town': '下陈街道',
#   'county': '椒江区',
#   'StationName': '下陈',
#   'fFy': '371.0',
#   'dFy': '225.0',
#   'RR': '998.0',
#   'Tx': '289.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.59306',
#   'lon': '121.4592'},
#  {'IIiii': 'K8108',
#   'city': '台州',
#   'town': '章安街道',
#   'county': '椒江区',
#   'StationName': '柏树里',
#   'fFy': '349.0',
#   'dFy': '253.0',
#   'RR': '1282.0',
#   'Tx': '304.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.73028',
#   'lon': '121.4508'},
#  {'IIiii': 'K8109',
#   'city': '台州',
#   'town': '三甲街道',
#   'county': '椒江区',
#   'StationName': '新佳果',
#   'fFy': '351.0',
#   'dFy': '214.0',
#   'RR': '963.0',
#   'Tx': '292.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.61944',
#   'lon': '121.5092'},
#  {'IIiii': 'K8110',
#   'city': '台州',
#   'town': '大陈镇',
#   'county': '椒江区',
#   'StationName': '上大陈',
#   'fFy': '603.0',
#   'dFy': '198.0',
#   'RR': '652.0',
#   'Tx': '280.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.49639',
#   'lon': '121.9056'},
#  {'IIiii': 'K8111',
#   'city': '台州',
#   'town': '前所街道',
#   'county': '椒江区',
#   'StationName': '二桥',
#   'fFy': '404.0',
#   'dFy': '226.0',
#   'RR': '487.0',
#   'Tx': '294.0',
#   'Tn': '255.0',
#   'VV': '607.0',
#   'lat': '28.69444',
#   'lon': '121.4744'},
#  {'IIiii': 'K8112',
#   'city': '台州',
#   'town': '海门街道',
#   'county': '椒江区',
#   'StationName': '岳头村',
#   'fFy': '280.0',
#   'dFy': '284.0',
#   'RR': '1112.0',
#   'Tx': '286.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.66417',
#   'lon': '121.4556'},
#  {'IIiii': 'K8113',
#   'city': '台州',
#   'town': '海虹街道',
#   'county': '椒江区',
#   'StationName': '污水厂',
#   'fFy': '254.0',
#   'dFy': '227.0',
#   'RR': '853.0',
#   'Tx': '296.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '28.64',
#   'lon': '121.5019'},
#  {'IIiii': 'K8114',
#   'city': '台州',
#   'town': '三甲街道',
#   'county': '椒江区',
#   'StationName': '雷达站',
#   'fFy': '305.0',
#   'dFy': '215.0',
#   'RR': '1233.0',
#   'Tx': '301.0',
#   'Tn': '256.0',
#   'VV': '1192.0',
#   'lat': '28.61722',
#   'lon': '121.522441'},
#  {'IIiii': 'K8115',
#   'city': '台州',
#   'town': '洪家街道',
#   'county': '椒江区',
#   'StationName': '挡港桥',
#   'fFy': '310.0',
#   'dFy': '252.0',
#   'RR': '1008.0',
#   'Tx': '294.0',
#   'Tn': '261.0',
#   'VV': '9999.0',
#   'lat': '28.59028',
#   'lon': '121.3997'},
#  {'IIiii': 'K8116',
#   'city': '台州',
#   'town': '大陈镇',
#   'county': '椒江区',
#   'StationName': '一江山',
#   'fFy': '423.0',
#   'dFy': '216.0',
#   'RR': '880.0',
#   'Tx': '292.0',
#   'Tn': '255.0',
#   'VV': '508.0',
#   'lat': '28.60861',
#   'lon': '121.8156'},
#  {'IIiii': 'K8118',
#   'city': '台州',
#   'town': '葭芷街道',
#   'county': '椒江区',
#   'StationName': '乌石',
#   'fFy': '342.0',
#   'dFy': '205.0',
#   'RR': '1375.0',
#   'Tx': '301.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '28.68333',
#   'lon': '121.375'},
#  {'IIiii': 'K8120',
#   'city': '台州',
#   'town': '海门街道',
#   'county': '椒江区',
#   'StationName': '台州湾大桥',
#   'fFy': '469.0',
#   'dFy': '233.0',
#   'RR': '0.0',
#   'Tx': '298.0',
#   'Tn': '249.0',
#   'VV': '9999.0',
#   'lat': '28.67805',
#   'lon': '121.5119'},
#  {'IIiii': 'K8191',
#   'city': '台州',
#   'town': '前所街道',
#   'county': '椒江区',
#   'StationName': '新民小学',
#   'fFy': '288.0',
#   'dFy': '237.0',
#   'RR': '1332.0',
#   'Tx': '298.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.70583',
#   'lon': '121.4144'},
#  {'IIiii': 'K8201',
#   'city': '台州',
#   'town': '东城街道',
#   'county': '黄岩区',
#   'StationName': '气象大楼',
#   'fFy': '278.0',
#   'dFy': '250.0',
#   'RR': '1575.0',
#   'Tx': '283.0',
#   'Tn': '254.0',
#   'VV': '1244.0',
#   'lat': '28.6525',
#   'lon': '121.28'},
#  {'IIiii': 'K8202',
#   'city': '台州',
#   'town': '宁溪镇',
#   'county': '黄岩区',
#   'StationName': '宁溪',
#   'fFy': '368.0',
#   'dFy': '350.0',
#   'RR': '2315.0',
#   'Tx': '275.0',
#   'Tn': '248.0',
#   'VV': '9999.0',
#   'lat': '28.59167',
#   'lon': '120.9753'},
#  {'IIiii': 'K8203',
#   'city': '台州',
#   'town': '沙埠镇',
#   'county': '黄岩区',
#   'StationName': '沙埠',
#   'fFy': '305.0',
#   'dFy': '296.0',
#   'RR': '2066.0',
#   'Tx': '283.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.54806',
#   'lon': '121.1744'},
#  {'IIiii': 'K8204',
#   'city': '台州',
#   'town': '北洋镇',
#   'county': '黄岩区',
#   'StationName': '长潭',
#   'fFy': '390.0',
#   'dFy': '360.0',
#   'RR': '2258.0',
#   'Tx': '266.0',
#   'Tn': '249.0',
#   'VV': '9999.0',
#   'lat': '28.61083',
#   'lon': '121.0583'},
#  {'IIiii': 'K8205',
#   'city': '台州',
#   'town': '头陀镇',
#   'county': '黄岩区',
#   'StationName': '头陀',
#   'fFy': '284.0',
#   'dFy': '349.0',
#   'RR': '2446.0',
#   'Tx': '269.0',
#   'Tn': '255.0',
#   'VV': '1358.0',
#   'lat': '28.67417',
#   'lon': '121.1369'},
#  {'IIiii': 'K8206',
#   'city': '台州',
#   'town': '富山乡',
#   'county': '黄岩区',
#   'StationName': '富山',
#   'fFy': '330.0',
#   'dFy': '352.0',
#   'RR': '2708.0',
#   'Tx': '240.0',
#   'Tn': '222.0',
#   'VV': '9999.0',
#   'lat': '28.53583',
#   'lon': '120.9131'},
#  {'IIiii': 'K8207',
#   'city': '台州',
#   'town': '屿头乡',
#   'county': '黄岩区',
#   'StationName': '白石',
#   'fFy': '215.0',
#   'dFy': '70.0',
#   'RR': '681.0',
#   'Tx': '228.0',
#   'Tn': '226.0',
#   'VV': '9999.0',
#   'lat': '28.67444',
#   'lon': '120.9375'},
#  {'IIiii': 'K8208',
#   'city': '台州',
#   'town': '屿头乡',
#   'county': '黄岩区',
#   'StationName': '屿头',
#   'fFy': '276.0',
#   'dFy': '350.0',
#   'RR': '3202.0',
#   'Tx': '265.0',
#   'Tn': '252.0',
#   'VV': '9999.0',
#   'lat': '28.65211',
#   'lon': '121.01093'},
#  {'IIiii': 'K8209',
#   'city': '台州',
#   'town': '上郑乡',
#   'county': '黄岩区',
#   'StationName': '下余',
#   'fFy': '256.0',
#   'dFy': '339.0',
#   'RR': '3388.0',
#   'Tx': '247.0',
#   'Tn': '239.0',
#   'VV': '9999.0',
#   'lat': '28.60583',
#   'lon': '120.8744'},
#  {'IIiii': 'K8210',
#   'city': '台州',
#   'town': '上垟乡',
#   'county': '黄岩区',
#   'StationName': '上垟',
#   'fFy': '328.0',
#   'dFy': '347.0',
#   'RR': '2968.0',
#   'Tx': '271.0',
#   'Tn': '250.0',
#   'VV': '9999.0',
#   'lat': '28.515366',
#   'lon': '121.008268'},
#  {'IIiii': 'K8212',
#   'city': '台州',
#   'town': '江口街道',
#   'county': '黄岩区',
#   'StationName': '江口',
#   'fFy': '296.0',
#   'dFy': '256.0',
#   'RR': '1540.0',
#   'Tx': '293.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.6903',
#   'lon': '121.3275'},
#  {'IIiii': 'K8213',
#   'city': '台州',
#   'town': '院桥镇',
#   'county': '黄岩区',
#   'StationName': '院桥',
#   'fFy': '340.0',
#   'dFy': '76.0',
#   'RR': '1352.0',
#   'Tx': '300.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '28.54972',
#   'lon': '121.2781'},
#  {'IIiii': 'K8214',
#   'city': '台州',
#   'town': '高桥街道',
#   'county': '黄岩区',
#   'StationName': '高桥',
#   'fFy': '349.0',
#   'dFy': '353.0',
#   'RR': '1211.0',
#   'Tx': '279.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.58444',
#   'lon': '121.2314'},
#  {'IIiii': 'K8215',
#   'city': '台州',
#   'town': '新前街道',
#   'county': '黄岩区',
#   'StationName': '新前',
#   'fFy': '343.0',
#   'dFy': '161.0',
#   'RR': '1628.0',
#   'Tx': '266.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.68139',
#   'lon': '121.2067'},
#  {'IIiii': 'K8216',
#   'city': '台州',
#   'town': '茅畲乡',
#   'county': '黄岩区',
#   'StationName': '茅畲',
#   'fFy': '325.0',
#   'dFy': '353.0',
#   'RR': '2747.0',
#   'Tx': '275.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '28.595',
#   'lon': '121.1314'},
#  {'IIiii': 'K8217',
#   'city': '台州',
#   'town': '澄江街道',
#   'county': '黄岩区',
#   'StationName': '澄江',
#   'fFy': '349.0',
#   'dFy': '352.0',
#   'RR': '1691.0',
#   'Tx': '280.0',
#   'Tn': '257.0',
#   'VV': '1202.0',
#   'lat': '28.63222',
#   'lon': '121.1736'},
#  {'IIiii': 'K8218',
#   'city': '台州',
#   'town': '北城街道',
#   'county': '黄岩区',
#   'StationName': '科技学院',
#   'fFy': '342.0',
#   'dFy': '219.0',
#   'RR': '1568.0',
#   'Tx': '284.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.66945',
#   'lon': '121.2539'},
#  {'IIiii': 'K8220',
#   'city': '台州',
#   'town': '北洋镇',
#   'county': '黄岩区',
#   'StationName': '北洋',
#   'fFy': '377.0',
#   'dFy': '358.0',
#   'RR': '2535.0',
#   'Tx': '280.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.63056',
#   'lon': '121.0978'},
#  {'IIiii': 'K8221',
#   'city': '台州',
#   'town': '平田乡',
#   'county': '黄岩区',
#   'StationName': '平田',
#   'fFy': '356.0',
#   'dFy': '219.0',
#   'RR': '3258.0',
#   'Tx': '262.0',
#   'Tn': '235.0',
#   'VV': '9999.0',
#   'lat': '28.53806',
#   'lon': '121.0739'},
#  {'IIiii': 'K8222',
#   'city': '台州',
#   'town': '上郑乡',
#   'county': '黄岩区',
#   'StationName': '大寺基',
#   'fFy': '257.0',
#   'dFy': '353.0',
#   'RR': '4460.0',
#   'Tx': '211.0',
#   'Tn': '205.0',
#   'VV': '9999.0',
#   'lat': '28.58417',
#   'lon': '120.7997'},
#  {'IIiii': 'K8224',
#   'city': '台州',
#   'town': '上郑乡',
#   'county': '黄岩区',
#   'StationName': '黄岩大瀑布',
#   'fFy': '349.0',
#   'dFy': '352.0',
#   'RR': '1279.0',
#   'Tx': '272.0',
#   'Tn': '257.0',
#   'VV': '1202.0',
#   'lat': '28.60472',
#   'lon': '120.8556'},
#  {'IIiii': 'K8225',
#   'city': '台州',
#   'town': '宁溪镇',
#   'county': '黄岩区',
#   'StationName': '牌门',
#   'fFy': '285.0',
#   'dFy': '345.0',
#   'RR': '3069.0',
#   'Tx': '264.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.53722',
#   'lon': '120.9522'},
#  {'IIiii': 'K8226',
#   'city': '台州',
#   'town': '西城街道',
#   'county': '黄岩区',
#   'StationName': '委羽山',
#   'fFy': '350.0',
#   'dFy': '190.0',
#   'RR': '775.0',
#   'Tx': '282.0',
#   'Tn': '250.0',
#   'VV': '9999.0',
#   'lat': '28.62472',
#   'lon': '121.2397'},
#  {'IIiii': 'K8227',
#   'city': '台州',
#   'town': '南城街道',
#   'county': '黄岩区',
#   'StationName': '十里铺',
#   'fFy': '342.0',
#   'dFy': '331.0',
#   'RR': '1467.0',
#   'Tx': '282.0',
#   'Tn': '250.0',
#   'VV': '9999.0',
#   'lat': '28.6125',
#   'lon': '121.2672'},
#  {'IIiii': 'K8228',
#   'city': '台州',
#   'town': '江口街道',
#   'county': '黄岩区',
#   'StationName': '江心屿',
#   'fFy': '360.0',
#   'dFy': '232.0',
#   'RR': '1339.0',
#   'Tx': '295.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.70555',
#   'lon': '121.3256'},
#  {'IIiii': 'K8270',
#   'city': '台州',
#   'town': '上郑乡',
#   'county': '黄岩区',
#   'StationName': '东亚山庄',
#   'fFy': '459.0',
#   'dFy': '354.0',
#   'RR': '3546.0',
#   'Tx': '212.0',
#   'Tn': '206.0',
#   'VV': '9999.0',
#   'lat': '28.59833',
#   'lon': '120.82'},
#  {'IIiii': 'K8271',
#   'city': '台州',
#   'town': '富山乡',
#   'county': '黄岩区',
#   'StationName': '外金',
#   'fFy': '317.0',
#   'dFy': '355.0',
#   'RR': '3518.0',
#   'Tx': '253.0',
#   'Tn': '229.0',
#   'VV': '9999.0',
#   'lat': '28.50778',
#   'lon': '120.8914'},
#  {'IIiii': 'K8272',
#   'city': '台州',
#   'town': '宁溪镇',
#   'county': '黄岩区',
#   'StationName': '牌门B',
#   'fFy': '285.0',
#   'dFy': '359.0',
#   'RR': '2908.0',
#   'Tx': '264.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.53622',
#   'lon': '120.9522'},
#  {'IIiii': 'K8274',
#   'city': '台州',
#   'town': '上垟乡',
#   'county': '黄岩区',
#   'StationName': '前思岙',
#   'fFy': '204.0',
#   'dFy': '356.0',
#   'RR': '3881.0',
#   'Tx': '252.0',
#   'Tn': '245.0',
#   'VV': '9999.0',
#   'lat': '28.48611',
#   'lon': '121.0247'},
#  {'IIiii': 'K8282',
#   'city': '台州',
#   'town': '宁溪镇',
#   'county': '黄岩区',
#   'StationName': '宁溪B',
#   'fFy': '362.0',
#   'dFy': '359.0',
#   'RR': '2525.0',
#   'Tx': '273.0',
#   'Tn': '248.0',
#   'VV': '9999.0',
#   'lat': '28.59067',
#   'lon': '120.9753'},
#  {'IIiii': 'K8283',
#   'city': '台州',
#   'town': '头陀镇',
#   'county': '黄岩区',
#   'StationName': '柑橘所',
#   'fFy': '328.0',
#   'dFy': '347.0',
#   'RR': '1995.0',
#   'Tx': '277.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '28.64278',
#   'lon': '121.1564'},
#  {'IIiii': 'K8301',
#   'city': '台州',
#   'town': '路北街道',
#   'county': '路桥区',
#   'StationName': '路桥',
#   'fFy': '304.0',
#   'dFy': '232.0',
#   'RR': '1178.0',
#   'Tx': '299.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.57528',
#   'lon': '121.3503'},
#  {'IIiii': 'K8302',
#   'city': '台州',
#   'town': '横街镇',
#   'county': '路桥区',
#   'StationName': '横街',
#   'fFy': '316.0',
#   'dFy': '232.0',
#   'RR': '729.0',
#   'Tx': '298.0',
#   'Tn': '254.0',
#   'VV': '9999.0',
#   'lat': '28.52778',
#   'lon': '121.4456'},
#  {'IIiii': 'K8303',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '金清',
#   'fFy': '346.0',
#   'dFy': '215.0',
#   'RR': '1006.0',
#   'Tx': '298.0',
#   'Tn': '259.0',
#   'VV': '1092.0',
#   'lat': '28.51583',
#   'lon': '121.4972'},
#  {'IIiii': 'K8304',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '白果',
#   'fFy': '560.0',
#   'dFy': '237.0',
#   'RR': '341.0',
#   'Tx': '279.0',
#   'Tn': '246.0',
#   'VV': '9999.0',
#   'lat': '28.48389',
#   'lon': '121.6219'},
#  {'IIiii': 'K8305',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '黄琅',
#   'fFy': '394.0',
#   'dFy': '233.0',
#   'RR': '1361.0',
#   'Tx': '293.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.52611',
#   'lon': '121.5967'},
#  {'IIiii': 'K8306',
#   'city': '台州',
#   'town': '桐屿街道',
#   'county': '路桥区',
#   'StationName': '桐屿',
#   'fFy': '261.0',
#   'dFy': '204.0',
#   'RR': '1120.0',
#   'Tx': '301.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.58556',
#   'lon': '121.3344'},
#  {'IIiii': 'K8307',
#   'city': '台州',
#   'town': '路南街道',
#   'county': '路桥区',
#   'StationName': '机场',
#   'fFy': '346.0',
#   'dFy': '225.0',
#   'RR': '981.0',
#   'Tx': '293.0',
#   'Tn': '261.0',
#   'VV': '9999.0',
#   'lat': '28.55528',
#   'lon': '121.4222'},
#  {'IIiii': 'K8308',
#   'city': '台州',
#   'town': '新桥镇',
#   'county': '路桥区',
#   'StationName': '新桥',
#   'fFy': '374.0',
#   'dFy': '223.0',
#   'RR': '918.0',
#   'Tx': '302.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.51194',
#   'lon': '121.4036'},
#  {'IIiii': 'K8309',
#   'city': '台州',
#   'town': '蓬街镇',
#   'county': '路桥区',
#   'StationName': '蓬街',
#   'fFy': '272.0',
#   'dFy': '226.0',
#   'RR': '660.0',
#   'Tx': '306.0',
#   'Tn': '256.0',
#   'VV': '9999.0',
#   'lat': '28.55445',
#   'lon': '121.4694'},
#  {'IIiii': 'K8310',
#   'city': '台州',
#   'town': '峰江街道',
#   'county': '路桥区',
#   'StationName': '峰江',
#   'fFy': '389.0',
#   'dFy': '235.0',
#   'RR': '988.0',
#   'Tx': '289.0',
#   'Tn': '252.0',
#   'VV': '9999.0',
#   'lat': '28.54861',
#   'lon': '121.3681'},
#  {'IIiii': 'K8311',
#   'city': '台州',
#   'town': '螺洋街道',
#   'county': '路桥区',
#   'StationName': '水厂',
#   'fFy': '328.0',
#   'dFy': '239.0',
#   'RR': '1147.0',
#   'Tx': '304.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.56083',
#   'lon': '121.33'},
#  {'IIiii': 'K8312',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '农垦场',
#   'fFy': '392.0',
#   'dFy': '204.0',
#   'RR': '1229.0',
#   'Tx': '297.0',
#   'Tn': '254.0',
#   'VV': '9999.0',
#   'lat': '28.50805',
#   'lon': '121.5872'},
#  {'IIiii': 'K8313',
#   'city': '台州',
#   'town': '蓬街镇',
#   'county': '路桥区',
#   'StationName': '启明村',
#   'fFy': '355.0',
#   'dFy': '232.0',
#   'RR': '1019.0',
#   'Tx': '297.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '28.56807',
#   'lon': '121.51892'},
#  {'IIiii': 'K8314',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '白果备份',
#   'fFy': '560.0',
#   'dFy': '237.0',
#   'RR': '446.0',
#   'Tx': '282.0',
#   'Tn': '246.0',
#   'VV': '9999.0',
#   'lat': '28.48361',
#   'lon': '121.6217'},
#  {'IIiii': 'K8315',
#   'city': '台州',
#   'town': ' 金清镇',
#   'county': '路桥区',
#   'StationName': '三山',
#   'fFy': '554.0',
#   'dFy': '221.0',
#   'RR': '860.0',
#   'Tx': '286.0',
#   'Tn': '252.0',
#   'VV': '609.0',
#   'lat': '28.56139',
#   'lon': '121.5944'},
#  {'IIiii': 'K8316',
#   'city': '台州',
#   'town': ' 金清镇',
#   'county': '路桥区',
#   'StationName': '鹁鸪嘴',
#   'fFy': '480.0',
#   'dFy': '113.0',
#   'RR': '823.0',
#   'Tx': '295.0',
#   'Tn': '253.0',
#   'VV': '569.0',
#   'lat': '28.55056',
#   'lon': '121.6422'},
#  {'IIiii': 'K8317',
#   'city': '台州',
#   'town': '桐屿街道',
#   'county': '路桥区',
#   'StationName': '凉溪',
#   'fFy': '343.0',
#   'dFy': '260.0',
#   'RR': '1422.0',
#   'Tx': '290.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.61778',
#   'lon': '121.3067'},
#  {'IIiii': 'K8318',
#   'city': '台州',
#   'town': '螺洋街道',
#   'county': '路桥区',
#   'StationName': '东风村',
#   'fFy': '355.0',
#   'dFy': '205.0',
#   'RR': '1124.0',
#   'Tx': '298.0',
#   'Tn': '253.0',
#   'VV': '2583.0',
#   'lat': '28.56417',
#   'lon': '121.3083'},
#  {'IIiii': 'K8319',
#   'city': '台州',
#   'town': ' 金清镇',
#   'county': '路桥区',
#   'StationName': '三山B',
#   'fFy': '17.0',
#   'dFy': '183.0',
#   'RR': '937.0',
#   'Tx': '286.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.56139',
#   'lon': '121.5944'},
#  {'IIiii': 'K8320',
#   'city': '台州',
#   'town': ' 金清镇',
#   'county': '路桥区',
#   'StationName': '湖屿岛',
#   'fFy': '515.0',
#   'dFy': '355.0',
#   'RR': '289.0',
#   'Tx': '293.0',
#   'Tn': '254.0',
#   'VV': '658.0',
#   'lat': '28.45833',
#   'lon': '121.6653'},
#  {'IIiii': 'K8321',
#   'city': '台州',
#   'town': '峰江街道',
#   'county': '路桥区',
#   'StationName': '保全小学',
#   'fFy': '314.0',
#   'dFy': '234.0',
#   'RR': '945.0',
#   'Tx': '301.0',
#   'Tn': '262.0',
#   'VV': '9999.0',
#   'lat': '28.52889',
#   'lon': '121.3761'},
#  {'IIiii': 'K8322',
#   'city': '台州',
#   'town': '金清镇',
#   'county': '路桥区',
#   'StationName': '路桥高速',
#   'fFy': '359.0',
#   'dFy': '221.0',
#   'RR': '627.0',
#   'Tx': '301.0',
#   'Tn': '251.0',
#   'VV': '1337.0',
#   'lat': '28.55556',
#   'lon': '121.5392'},
#  {'IIiii': 'K8401',
#   'city': '台州',
#   'town': '石桥头镇',
#   'county': '温岭市',
#   'StationName': '石桥头',
#   'fFy': '399.0',
#   'dFy': '240.0',
#   'RR': '1224.0',
#   'Tx': '305.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '28.34945',
#   'lon': '121.4606'},
#  {'IIiii': 'K8402',
#   'city': '台州',
#   'town': '泽国镇',
#   'county': '温岭市',
#   'StationName': '黄茅山',
#   'fFy': '312.0',
#   'dFy': '212.0',
#   'RR': '1249.0',
#   'Tx': '288.0',
#   'Tn': '246.0',
#   'VV': '9999.0',
#   'lat': '28.52972',
#   'lon': '121.3078'},
#  {'IIiii': 'K8403',
#   'city': '台州',
#   'town': '大溪镇',
#   'county': '温岭市',
#   'StationName': '大溪',
#   'fFy': '346.0',
#   'dFy': '360.0',
#   'RR': '1826.0',
#   'Tx': '298.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.49111',
#   'lon': '121.2411'},
#  {'IIiii': 'K8404',
#   'city': '台州',
#   'town': '松门镇',
#   'county': '温岭市',
#   'StationName': '松门',
#   'fFy': '420.0',
#   'dFy': '232.0',
#   'RR': '1297.0',
#   'Tx': '295.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.37111',
#   'lon': '121.5664'},
#  {'IIiii': 'K8405',
#   'city': '台州',
#   'town': '坞根镇',
#   'county': '温岭市',
#   'StationName': '坞根',
#   'fFy': '303.0',
#   'dFy': '359.0',
#   'RR': '1422.0',
#   'Tx': '304.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '28.32472',
#   'lon': '121.2611'},
#  {'IIiii': 'K8406',
#   'city': '台州',
#   'town': '横峰街道',
#   'county': '温岭市',
#   'StationName': '横峰',
#   'fFy': '359.0',
#   'dFy': '241.0',
#   'RR': '1437.0',
#   'Tx': '305.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.4475',
#   'lon': '121.3258'},
#  {'IIiii': 'K8407',
#   'city': '台州',
#   'town': '石塘镇',
#   'county': '温岭市',
#   'StationName': '石塘渔港',
#   'fFy': '555.0',
#   'dFy': '231.0',
#   'RR': '751.0',
#   'Tx': '286.0',
#   'Tn': '248.0',
#   'VV': '395.0',
#   'lat': '28.24639',
#   'lon': '121.6039'},
#  {'IIiii': 'K8408',
#   'city': '台州',
#   'town': '新河镇',
#   'county': '温岭市',
#   'StationName': '新河',
#   'fFy': '381.0',
#   'dFy': '276.0',
#   'RR': '889.0',
#   'Tx': '301.0',
#   'Tn': '256.0',
#   'VV': '9999.0',
#   'lat': '28.47806',
#   'lon': '121.4594'},
#  {'IIiii': 'K8409',
#   'city': '台州',
#   'town': '箬横镇',
#   'county': '温岭市',
#   'StationName': '东海塘',
#   'fFy': '462.0',
#   'dFy': '220.0',
#   'RR': '548.0',
#   'Tx': '294.0',
#   'Tn': '254.0',
#   'VV': '667.0',
#   'lat': '28.42222',
#   'lon': '121.6081'},
#  {'IIiii': 'K8410',
#   'city': '台州',
#   'town': '城南镇',
#   'county': '温岭市',
#   'StationName': '岙环',
#   'fFy': '400.0',
#   'dFy': '357.0',
#   'RR': '1311.0',
#   'Tx': '298.0',
#   'Tn': '0.0',
#   'VV': '9999.0',
#   'lat': '28.28611',
#   'lon': '121.3994'},
#  {'IIiii': 'K8411',
#   'city': '台州',
#   'town': '温峤镇',
#   'county': '温岭市',
#   'StationName': '温峤',
#   'fFy': '518.0',
#   'dFy': '357.0',
#   'RR': '1308.0',
#   'Tx': '300.0',
#   'Tn': '254.0',
#   'VV': '9999.0',
#   'lat': '28.38389',
#   'lon': '121.3003'},
#  {'IIiii': 'K8412',
#   'city': '台州',
#   'town': '箬横镇',
#   'county': '温岭市',
#   'StationName': '箬横',
#   'fFy': '272.0',
#   'dFy': '300.0',
#   'RR': '1117.0',
#   'Tx': '302.0',
#   'Tn': '261.0',
#   'VV': '9999.0',
#   'lat': '28.39889',
#   'lon': '121.5228'},
#  {'IIiii': 'K8413',
#   'city': '台州',
#   'town': '滨海镇',
#   'county': '温岭市',
#   'StationName': '滨海',
#   'fFy': '417.0',
#   'dFy': '222.0',
#   'RR': '1254.0',
#   'Tx': '296.0',
#   'Tn': '254.0',
#   'VV': '1050.0',
#   'lat': '28.45056',
#   'lon': '121.5589'},
#  {'IIiii': 'K8414',
#   'city': '台州',
#   'town': '大溪镇',
#   'county': '温岭市',
#   'StationName': '太湖山',
#   'fFy': '460.0',
#   'dFy': '205.0',
#   'RR': '1674.0',
#   'Tx': '263.0',
#   'Tn': '235.0',
#   'VV': '9999.0',
#   'lat': '28.49917',
#   'lon': '121.2019'},
#  {'IIiii': 'K8415',
#   'city': '台州',
#   'town': '松门镇',
#   'county': '温岭市',
#   'StationName': '九洞门',
# ...
#   'Tn': '254.0',
#   'VV': '9999.0',
#   'lat': '29.15389',
#   'lon': '120.995'},
#  {'IIiii': 'K8770',
#   'city': '台州',
#   'town': '白鹤镇',
#   'county': '天台县',
#   'StationName': '左溪',
#   'fFy': '147.0',
#   'dFy': '344.0',
#   'RR': '2555.0',
#   'Tx': '239.0',
#   'Tn': '229.0',
#   'VV': '9999.0',
#   'lat': '29.28889',
#   'lon': '120.915'},
#  {'IIiii': 'K8771',
#   'city': '台州',
#   'town': '街头镇',
#   'county': '天台县',
#   'StationName': '溪地A',
#   'fFy': '186.0',
#   'dFy': '356.0',
#   'RR': '2600.0',
#   'Tx': '264.0',
#   'Tn': '245.0',
#   'VV': '9999.0',
#   'lat': '29.05139',
#   'lon': '120.8411'},
#  {'IIiii': 'K8772',
#   'city': '台州',
#   'town': '石梁镇',
#   'county': '天台县',
#   'StationName': '大同寺',
#   'fFy': '206.0',
#   'dFy': '355.0',
#   'RR': '3085.0',
#   'Tx': '255.0',
#   'Tn': '243.0',
#   'VV': '9999.0',
#   'lat': '29.29333',
#   'lon': '121.1458'},
#  {'IIiii': 'K8773',
#   'city': '台州',
#   'town': '坦头镇',
#   'county': '天台县',
#   'StationName': '欢岙',
#   'fFy': '257.0',
#   'dFy': '318.0',
#   'RR': '3413.0',
#   'Tx': '257.0',
#   'Tn': '241.0',
#   'VV': '9999.0',
#   'lat': '29.18444',
#   'lon': '121.1128'},
#  {'IIiii': 'K8774',
#   'city': '台州',
#   'town': '三州乡',
#   'county': '天台县',
#   'StationName': '下屋村',
#   'fFy': '205.0',
#   'dFy': '350.0',
#   'RR': '2328.0',
#   'Tx': '248.0',
#   'Tn': '238.0',
#   'VV': '9999.0',
#   'lat': '29.21722',
#   'lon': '120.8017'},
#  {'IIiii': 'K8801',
#   'city': '台州',
#   'town': '亭旁镇',
#   'county': '三门县',
#   'StationName': '亭旁',
#   'fFy': '236.0',
#   'dFy': '249.0',
#   'RR': '2702.0',
#   'Tx': '273.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '29.04361',
#   'lon': '121.3403'},
#  {'IIiii': 'K8802',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '三角塘',
#   'fFy': '323.0',
#   'dFy': '239.0',
#   'RR': '429.0',
#   'Tx': '295.0',
#   'Tn': '259.0',
#   'VV': '962.0',
#   'lat': '28.93806',
#   'lon': '121.7144'},
#  {'IIiii': 'K8803',
#   'city': '台州',
#   'town': '蛇蟠乡',
#   'county': '三门县',
#   'StationName': '蛇蟠',
#   'fFy': '279.0',
#   'dFy': '189.0',
#   'RR': '1513.0',
#   'Tx': '288.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '29.16195',
#   'lon': '121.5706'},
#  {'IIiii': 'K8805',
#   'city': '台州',
#   'town': '横渡镇',
#   'county': '三门县',
#   'StationName': '横渡',
#   'fFy': '315.0',
#   'dFy': '291.0',
#   'RR': '1302.0',
#   'Tx': '282.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '29.01167',
#   'lon': '121.5094'},
#  {'IIiii': 'K8806',
#   'city': '台州',
#   'town': '亭旁镇',
#   'county': '三门县',
#   'StationName': '百两岗',
#   'fFy': '318.0',
#   'dFy': '75.0',
#   'RR': '3565.0',
#   'Tx': '251.0',
#   'Tn': '231.0',
#   'VV': '9999.0',
#   'lat': '28.98389',
#   'lon': '121.3986'},
#  {'IIiii': 'K8807',
#   'city': '台州',
#   'town': '珠岙镇',
#   'county': '三门县',
#   'StationName': '高枧',
#   'fFy': '220.0',
#   'dFy': '192.0',
#   'RR': '2477.0',
#   'Tx': '273.0',
#   'Tn': '253.0',
#   'VV': '1642.0',
#   'lat': '29.05',
#   'lon': '121.2208'},
#  {'IIiii': 'K8808',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '山场村',
#   'fFy': '319.0',
#   'dFy': '288.0',
#   'RR': '2090.0',
#   'Tx': '292.0',
#   'Tn': '256.0',
#   'VV': '9999.0',
#   'lat': '28.8675',
#   'lon': '121.5128'},
#  {'IIiii': 'K8809',
#   'city': '台州',
#   'town': '花桥镇',
#   'county': '三门县',
#   'StationName': '花桥',
#   'fFy': '298.0',
#   'dFy': '266.0',
#   'RR': '2022.0',
#   'Tx': '290.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.92083',
#   'lon': '121.4714'},
#  {'IIiii': 'K8810',
#   'city': '台州',
#   'town': '健跳镇',
#   'county': '三门县',
#   'StationName': '健跳',
#   'fFy': '288.0',
#   'dFy': '201.0',
#   'RR': '1505.0',
#   'Tx': '289.0',
#   'Tn': '260.0',
#   'VV': '2213.0',
#   'lat': '29.01389',
#   'lon': '121.6083'},
#  {'IIiii': 'K8811',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '浬浦',
#   'fFy': '341.0',
#   'dFy': '183.0',
#   'RR': '1006.0',
#   'Tx': '270.0',
#   'Tn': '249.0',
#   'VV': '9999.0',
#   'lat': '28.97111',
#   'lon': '121.5808'},
#  {'IIiii': 'K8812',
#   'city': '台州',
#   'town': '海润街道',
#   'county': '三门县',
#   'StationName': '叶家村',
#   'fFy': '196.0',
#   'dFy': '316.0',
#   'RR': '1851.0',
#   'Tx': '285.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '29.0675',
#   'lon': '121.4881'},
#  {'IIiii': 'K8813',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '鹤井村',
#   'fFy': '376.0',
#   'dFy': '208.0',
#   'RR': '810.0',
#   'Tx': '286.0',
#   'Tn': '254.0',
#   'VV': '1037.0',
#   'lat': '28.87583',
#   'lon': '121.6383'},
#  {'IIiii': 'K8814',
#   'city': '台州',
#   'town': '珠岙镇',
#   'county': '三门县',
#   'StationName': '珠岙',
#   'fFy': '319.0',
#   'dFy': '254.0',
#   'RR': '1852.0',
#   'Tx': '273.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '29.07444',
#   'lon': '121.2789'},
#  {'IIiii': 'K8815',
#   'city': '台州',
#   'town': '沙柳街道 ',
#   'county': '三门县',
#   'StationName': '沙柳',
#   'fFy': '331.0',
#   'dFy': '215.0',
#   'RR': '1163.0',
#   'Tx': '278.0',
#   'Tn': '250.0',
#   'VV': '9999.0',
#   'lat': '29.15222',
#   'lon': '121.4575'},
#  {'IIiii': 'K8816',
#   'city': '台州',
#   'town': '健跳镇',
#   'county': '三门县',
#   'StationName': '农业园',
#   'fFy': '261.0',
#   'dFy': '201.0',
#   'RR': '1359.0',
#   'Tx': '282.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '29.10389',
#   'lon': '121.6006'},
#  {'IIiii': 'K8817',
#   'city': '台州',
#   'town': '海游街道',
#   'county': '三门县',
#   'StationName': '悬诸',
#   'fFy': '269.0',
#   'dFy': '357.0',
#   'RR': '2660.0',
#   'Tx': '284.0',
#   'Tn': '251.0',
#   'VV': '9999.0',
#   'lat': '29.07528',
#   'lon': '121.405'},
#  {'IIiii': 'K8818',
#   'city': '台州',
#   'town': '亭旁镇',
#   'county': '三门县',
#   'StationName': '佃石',
#   'fFy': '267.0',
#   'dFy': '215.0',
#   'RR': '2624.0',
#   'Tx': '273.0',
#   'Tn': '248.0',
#   'VV': '9999.0',
#   'lat': '29.0025',
#   'lon': '121.3147'},
#  {'IIiii': 'K8819',
#   'city': '台州',
#   'town': '沙柳街道 ',
#   'county': '三门县',
#   'StationName': '板樟山',
#   'fFy': '268.0',
#   'dFy': '212.0',
#   'RR': '1728.0',
#   'Tx': '267.0',
#   'Tn': '243.0',
#   'VV': '9999.0',
#   'lat': '29.15861',
#   'lon': '121.3514'},
#  {'IIiii': 'K8820',
#   'city': '台州',
#   'town': '海润街道',
#   'county': '三门县',
#   'StationName': '滨海新城',
#   'fFy': '259.0',
#   'dFy': '248.0',
#   'RR': '1584.0',
#   'Tx': '288.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '29.12361',
#   'lon': '121.48'},
#  {'IIiii': 'K8821',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '浦坝港',
#   'fFy': '303.0',
#   'dFy': '230.0',
#   'RR': '1010.0',
#   'Tx': '287.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.92694',
#   'lon': '121.5833'},
#  {'IIiii': 'K8822',
#   'city': '台州',
#   'town': '沙柳街道',
#   'county': '三门县',
#   'StationName': '下南山',
#   'fFy': '272.0',
#   'dFy': '213.0',
#   'RR': '1695.0',
#   'Tx': '268.0',
#   'Tn': '242.0',
#   'VV': '9999.0',
#   'lat': '29.15083',
#   'lon': '121.3683'},
#  {'IIiii': 'K8823',
#   'city': '台州',
#   'town': '健跳镇',
#   'county': '三门县',
#   'StationName': '农气基地',
#   'fFy': '277.0',
#   'dFy': '186.0',
#   'RR': '1533.0',
#   'Tx': '294.0',
#   'Tn': '259.0',
#   'VV': '9999.0',
#   'lat': '29.10861',
#   'lon': '121.5767'},
#  {'IIiii': 'K8824',
#   'city': '台州',
#   'town': '横渡镇',
#   'county': '三门县',
#   'StationName': '东屏村',
#   'fFy': '291.0',
#   'dFy': '151.0',
#   'RR': '2089.0',
#   'Tx': '275.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '29.00889',
#   'lon': '121.4683'},
#  {'IIiii': 'K8825',
#   'city': '台州',
#   'town': '健跳镇',
#   'county': '三门县',
#   'StationName': '龙山',
#   'fFy': '362.0',
#   'dFy': '184.0',
#   'RR': '399.0',
#   'Tx': '276.0',
#   'Tn': '255.0',
#   'VV': '9999.0',
#   'lat': '29.06667',
#   'lon': '121.6792'},
#  {'IIiii': 'K8826',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '扩塘山',
#   'fFy': '381.0',
#   'dFy': '211.0',
#   'RR': '582.0',
#   'Tx': '292.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.89111',
#   'lon': '121.6617'},
#  {'IIiii': 'K8827',
#   'city': '台州',
#   'town': '浦坝港镇',
#   'county': '三门县',
#   'StationName': '扩塘山B',
#   'fFy': '387.0',
#   'dFy': '204.0',
#   'RR': '614.0',
#   'Tx': '289.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.89111',
#   'lon': '121.6617'},
#  {'IIiii': 'K8828',
#   'city': '台州',
#   'town': '亭旁镇',
#   'county': '三门县',
#   'StationName': '枧头村',
#   'fFy': '297.0',
#   'dFy': '336.0',
#   'RR': '3710.0',
#   'Tx': '258.0',
#   'Tn': '237.0',
#   'VV': '9999.0',
#   'lat': '29.02444',
#   'lon': '121.3881'},
#  {'IIiii': 'K8829',
#   'city': '台州',
#   'town': '珠岙镇',
#   'county': '三门县',
#   'StationName': '吴岙',
#   'fFy': '208.0',
#   'dFy': '343.0',
#   'RR': '2108.0',
#   'Tx': '277.0',
#   'Tn': '257.0',
#   'VV': '2704.0',
#   'lat': '29.05445',
#   'lon': '121.2419'},
#  {'IIiii': 'K8830',
#   'city': '台州',
#   'town': '蛇蟠乡',
#   'county': '三门县',
#   'StationName': '蛇蟠旅游',
#   'fFy': '276.0',
#   'dFy': '198.0',
#   'RR': '1359.0',
#   'Tx': '288.0',
#   'Tn': '260.0',
#   'VV': '993.0',
#   'lat': '29.16195',
#   'lon': '121.5706'},
#  {'IIiii': 'K8840',
#   'city': '台州',
#   'town': '海游街道',
#   'county': '三门县',
#   'StationName': '林场',
#   'fFy': '331.0',
#   'dFy': '170.0',
#   'RR': '3231.0',
#   'Tx': '235.0',
#   'Tn': '226.0',
#   'VV': '9999.0',
#   'lat': '29.04917',
#   'lon': '121.4242'},
#  {'IIiii': 'K8841',
#   'city': '台州',
#   'town': '健跳镇',
#   'county': '三门县',
#   'StationName': '三门湾',
#   'fFy': '308.0',
#   'dFy': '215.0',
#   'RR': '412.0',
#   'Tx': '296.0',
#   'Tn': '257.0',
#   'VV': '1233.0',
#   'lat': '29.11806',
#   'lon': '121.5811'},
#  {'IIiii': 'K8902',
#   'city': '台州',
#   'town': '横溪镇',
#   'county': '仙居县',
#   'StationName': '横溪',
#   'fFy': '152.0',
#   'dFy': '303.0',
#   'RR': '994.0',
#   'Tx': '271.0',
#   'Tn': '256.0',
#   'VV': '9999.0',
#   'lat': '28.72889',
#   'lon': '120.4772'},
#  {'IIiii': 'K8903',
#   'city': '台州',
#   'town': '朱溪镇',
#   'county': '仙居县',
#   'StationName': '朱溪',
#   'fFy': '200.0',
#   'dFy': '359.0',
#   'RR': '2694.0',
#   'Tx': '275.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.71806',
#   'lon': '120.7936'},
#  {'IIiii': 'K8904',
#   'city': '台州',
#   'town': '广度乡',
#   'county': '仙居县',
#   'StationName': '广度',
#   'fFy': '156.0',
#   'dFy': '128.0',
#   'RR': '0.0',
#   'Tx': '235.0',
#   'Tn': '226.0',
#   'VV': '9999.0',
#   'lat': '28.94639',
#   'lon': '120.7519'},
#  {'IIiii': 'K8905',
#   'city': '台州',
#   'town': '上张乡',
#   'county': '仙居县',
#   'StationName': '六亩田',
#   'fFy': '238.0',
#   'dFy': '340.0',
#   'RR': '2724.0',
#   'Tx': '257.0',
#   'Tn': '231.0',
#   'VV': '9999.0',
#   'lat': '28.62139',
#   'lon': '120.7147'},
#  {'IIiii': 'K8908',
#   'city': '台州',
#   'town': '田市镇',
#   'county': '仙居县',
#   'StationName': '柯思',
#   'fFy': '183.0',
#   'dFy': '206.0',
#   'RR': '3003.0',
#   'Tx': '269.0',
#   'Tn': '244.0',
#   'VV': '9999.0',
#   'lat': '28.66389',
#   'lon': '120.6708'},
#  {'IIiii': 'K8911',
#   'city': '台州',
#   'town': '淡竹乡',
#   'county': '仙居县',
#   'StationName': '淡竹',
#   'fFy': '219.0',
#   'dFy': '347.0',
#   'RR': '2344.0',
#   'Tx': '270.0',
#   'Tn': '247.0',
#   'VV': '9999.0',
#   'lat': '28.67194',
#   'lon': '120.5706'},
#  {'IIiii': 'K8912',
#   'city': '台州',
#   'town': '溪港乡',
#   'county': '仙居县',
#   'StationName': '溪港',
#   'fFy': '155.0',
#   'dFy': '354.0',
#   'RR': '2021.0',
#   'Tx': '252.0',
#   'Tn': '238.0',
#   'VV': '9999.0',
#   'lat': '28.57361',
#   'lon': '120.3961'},
#  {'IIiii': 'K8913',
#   'city': '台州',
#   'town': '横溪镇',
#   'county': '仙居县',
#   'StationName': '溪口',
#   'fFy': '140.0',
#   'dFy': '352.0',
#   'RR': '2042.0',
#   'Tx': '268.0',
#   'Tn': '241.0',
#   'VV': '9999.0',
#   'lat': '28.645',
#   'lon': '120.4797'},
#  {'IIiii': 'K8916',
#   'city': '台州',
#   'town': '安岭乡',
#   'county': '仙居县',
#   'StationName': '安岭',
#   'fFy': '249.0',
#   'dFy': '309.0',
#   'RR': '1599.0',
#   'Tx': '277.0',
#   'Tn': '234.0',
#   'VV': '9999.0',
#   'lat': '28.56083',
#   'lon': '120.3333'},
#  {'IIiii': 'K8917',
#   'city': '台州',
#   'town': '下各镇',
#   'county': '仙居县',
#   'StationName': '下各',
#   'fFy': '229.0',
#   'dFy': '283.0',
#   'RR': '1445.0',
#   'Tx': '272.0',
#   'Tn': '253.0',
#   'VV': '9999.0',
#   'lat': '28.83972',
#   'lon': '120.8778'},
#  {'IIiii': 'K8919',
#   'city': '台州',
#   'town': '大战乡',
#   'county': '仙居县',
#   'StationName': '对山',
#   'fFy': '203.0',
#   'dFy': '177.0',
#   'RR': '2777.0',
#   'Tx': '263.0',
#   'Tn': '231.0',
#   'VV': '9999.0',
#   'lat': '28.76056',
#   'lon': '120.775'},
#  {'IIiii': 'K8920',
#   'city': '台州',
#   'town': '横溪镇',
#   'county': '仙居县',
#   'StationName': '山岙',
#   'fFy': '227.0',
#   'dFy': '352.0',
#   'RR': '1856.0',
#   'Tx': '244.0',
#   'Tn': '233.0',
#   'VV': '9999.0',
#   'lat': '28.77944',
#   'lon': '120.4283'},
#  {'IIiii': 'K8921',
#   'city': '台州',
#   'town': '湫山乡',
#   'county': '仙居县',
#   'StationName': '蓄能站',
#   'fFy': '250.0',
#   'dFy': '311.0',
#   'RR': '1386.0',
#   'Tx': '238.0',
#   'Tn': '226.0',
#   'VV': '9999.0',
#   'lat': '28.63111',
#   'lon': '120.4019'},
#  {'IIiii': 'K8922',
#   'city': '台州',
#   'town': '福应街道',
#   'county': '仙居县',
#   'StationName': '工业园区',
#   'fFy': '245.0',
#   'dFy': '359.0',
#   'RR': '1569.0',
#   'Tx': '288.0',
#   'Tn': '252.0',
#   'VV': '9999.0',
#   'lat': '28.87944',
#   'lon': '120.8328'},
#  {'IIiii': 'K8923',
#   'city': '台州',
#   'town': '淡竹乡',
#   'county': '仙居县',
#   'StationName': '俞坑',
#   'fFy': '183.0',
#   'dFy': '216.0',
#   'RR': '1664.0',
#   'Tx': '250.0',
#   'Tn': '236.0',
#   'VV': '9999.0',
#   'lat': '28.54944',
#   'lon': '120.5878'},
#  {'IIiii': 'K8924',
#   'city': '台州',
#   'town': '官路镇',
#   'county': '仙居县',
#   'StationName': '谷坦',
#   'fFy': '176.0',
#   'dFy': '305.0',
#   'RR': '1841.0',
#   'Tx': '242.0',
#   'Tn': '233.0',
#   'VV': '9999.0',
#   'lat': '28.87833',
#   'lon': '120.6025'},
#  {'IIiii': 'K8925',
#   'city': '台州',
#   'town': '南峰街道',
#   'county': '仙居县',
#   'StationName': '南峰',
#   'fFy': '169.0',
#   'dFy': '272.0',
#   'RR': '1108.0',
#   'Tx': '268.0',
#   'Tn': '249.0',
#   'VV': '9999.0',
#   'lat': '28.825',
#   'lon': '120.7467'},
#  {'IIiii': 'K8926',
#   'city': '台州',
#   'town': '湫山乡',
#   'county': '仙居县',
#   'StationName': '湫山',
#   'fFy': '171.0',
#   'dFy': '244.0',
#   'RR': '862.0',
#   'Tx': '277.0',
#   'Tn': '248.0',
#   'VV': '9999.0',
#   'lat': '28.69833',
#   'lon': '120.4433'},
#  {'IIiii': 'K8927',
#   'city': '台州',
#   'town': '安洲街道',
#   'county': '仙居县',
#   'StationName': '四小',
#   'fFy': '226.0',
#   'dFy': '356.0',
#   'RR': '1672.0',
#   'Tx': '276.0',
#   'Tn': '258.0',
#   'VV': '9999.0',
#   'lat': '28.87278',
#   'lon': '120.7306'},
#  {'IIiii': 'K8928',
#   'city': '台州',
#   'town': '官路镇',
#   'county': '仙居县',
#   'StationName': '永狮',
#   'fFy': '286.0',
#   'dFy': '275.0',
#   'RR': '917.0',
#   'Tx': '283.0',
#   'Tn': '260.0',
#   'VV': '9999.0',
#   'lat': '28.81194',
#   'lon': '120.6328'},
#  {'IIiii': 'K8929',
#   'city': '台州',
#   'town': '白塔镇',
#   'county': '仙居县',
#   'StationName': '茶溪',
#   'fFy': '206.0',
#   'dFy': '348.0',
#   'RR': '1287.0',
#   'Tx': '283.0',
#   'Tn': '255.0',
#   'VV': '3488.0',
#   'lat': '28.775',
#   'lon': '120.5811'},
#  {'IIiii': 'K8942',
#   'city': '台州',
#   'town': '淡竹乡',
#   'county': '仙居县',
#   'StationName': '朱坑里',
#   'fFy': '235.0',
#   'dFy': '264.0',
#   'RR': '2864.0',
#   'Tx': '263.0',
#   'Tn': '235.0',
#   'VV': '9999.0',
#   'lat': '28.60417',
#   'lon': '120.6542'},
#  {'IIiii': 'K8945',
#   'city': '台州',
#   'town': '福应街道',
#   'county': '仙居县',
#   'StationName': '青尖山',
#   'fFy': '317.0',
#   'dFy': '354.0',
#   'RR': '2686.0',
#   'Tx': '225.0',
#   'Tn': '218.0',
#   'VV': '9999.0',
#   'lat': '28.91639',
#   'lon': '120.7275'},
#  {'IIiii': 'K8946',
#   'city': '台州',
#   'town': '田市镇',
#   'county': '仙居县',
#   'StationName': '公盂',
#   'fFy': '260.0',
#   'dFy': '351.0',
#   'RR': '2697.0',
#   'Tx': '244.0',
#   'Tn': '228.0',
#   'VV': '9999.0',
#   'lat': '28.63917',
#   'lon': '120.6425'},
#  {'IIiii': 'K8949',
#   'city': '台州',
#   'town': '上张乡',
#   'county': '仙居县',
#   'StationName': '天顶茶场',
#   'fFy': '284.0',
#   'dFy': '358.0',
#   'RR': '3414.0',
#   'Tx': '230.0',
#   'Tn': '215.0',
#   'VV': '9999.0',
#   'lat': '28.63583',
#   'lon': '120.8078'},
#  {'IIiii': 'K8982',
#   'city': '台州',
#   'town': '朱溪镇',
#   'county': '仙居县',
#   'StationName': '金竹寺',
#   'fFy': '160.0',
#   'dFy': '346.0',
#   'RR': '0.0',
#   'Tx': '281.0',
#   'Tn': '257.0',
#   'VV': '9999.0',
#   'lat': '28.63278',
#   'lon': '120.9031'},
#  {'IIiii': '58558',
#   'city': '金华',
#   'town': '吴宁街道',
#   'county': '东阳市',
#   'StationName': '东阳',
#   'fFy': '192.0',
#   'dFy': '308.0',
#   'RR': '7.0',
#   'Tx': '353.0',
#   'Tn': '279.0',
#   'VV': '16790.0',
#   'lat': '29.266666666666666',
#   'lon': '120.21666666666668'},
#  {'IIiii': '58646',
#   'city': '丽水',
#   'town': '南明山街道',
#   'county': '莲都区',
#   'StationName': '丽水',
#   'fFy': '115.0',
#   'dFy': '272.0',
#   'RR': '0.0',
#   'Tx': '367.0',
#   'Tn': '256.0',
#   'VV': '9706.0',
#   'lat': '28.45',
#   'lon': '119.91666666666669'},
#  {'IIiii': '58647',
#   'city': '丽水',
#   'town': '西街街道',
#   'county': '龙泉市',
#   'StationName': '龙泉',
#   'fFy': '155.0',
#   'dFy': '351.0',
#   'RR': '358.0',
#   'Tx': '337.0',
#   'Tn': '240.0',
#   'VV': '4174.0',
#   'lat': '28.08333333333333',
#   'lon': '119.13333333333334'}]

# %% [markdown]
# # 428data_class中的数据

# %%
class zdz_data:
    def __init__(self, start, end):
        self.start = start
        self.end = end  
    def read_csv(self):
        '''
        1.数据读取---此方法为测试方法
        2.数据分段---每天
        3.每天统计
        '''
        #         station_Mws = pd.read_csv("Mws_15.csv")
        #         station_Aws = pd.read_csv("Aws_15.csv")
        #         station_all = pd.concat([station_Aws, station_Mws])
        # station_all = pd.read_csv("data_zdz_height.csv")
        station_all = pd.read_csv("static/data/data_zdz_height.csv")
        return station_all
    def sql_data(self):
        conn = pymysql.connect(host="127.0.0.1",port=3306,user="root",passwd="051219",db="ZJSZDZDB")
        start = self.start 
        end = self.end 
        #print(start,end)
        sql_location = "select b.StationName,b.county,b.Town,b.lat,b.lon,b.IIiii,b.Height,tTime,dFy,fFy,T,Tx,Tn,VV,RR from\
            TAB_Mws2019 as a left join TAB_StationInfo as b on a.IIiii=b.IIiii where\
            (b.IIiii in (select IIiii from TAB_StationInfo where(City = '台州') and tTime between"
        sql_location = sql_location + " " + "'" +  start + "'" +  "  " + "and" + " " + "'" +  end + "'" + "))"
        df_location = pd.read_sql(sql_location , con=conn)
        return df_location
    def return_daylist(self):
        '''
        返回日期列表
        '''
        dates = []
        #         dt = datetime.datetime.strptime(self.start, "%Y-%m-%d")
        dt = dtt.datetime.strptime(self.start[0:10], "%Y-%m-%d")
        date = self.start[:10]
        yesday = dt+dtt.timedelta(-1)
        dates.append(yesday.strftime("%Y-%m-%d")[:10])
        while date <= self.end[:10]:
            dates.append(date)
            dt = dt + dtt.timedelta(1)
            date = dt.strftime("%Y-%m-%d")
        return dates
    def day_button(self,city,station_data):
        '''返回按钮组'''
        station_all = station_data
        dates = self.return_daylist()
        dailylist = []
        for i in range(len(dates)):
            daily = {
                "time":None,
                "rain":False,
                "wind":False,
                "tmax":False,
                "tmin":False,
                "view":False,
            }
            if i!=0:
                s_date = dates[i-1] + ' ' + '20:00'
                e_date = dates[i] + ' ' + '20:00'
                daily["time"] = dates[i]
                df_preday = station_all[(station_all['tTime'] >= s_date) & (station_all['tTime'] <= e_date)]
                # 统计标量
                temp_min = df_preday[(df_preday['Height'] < 6000) & (df_preday['T'] > -400)]['T'].min()
                temp_max = df_preday[(df_preday['Height'] < 6000) & (df_preday['T'] > -400)]['T'].max()
                vv = df_preday[(df_preday['VV'] > 0.1) & (df_preday['VV'] < 500)]['VV'].count()
                RR = df_preday[(df_preday['RR'] > 0.1) & (df_preday['RR'] < 8888)]['RR'].count()
                wind = df_preday[df_preday['fFy'] > 187]['fFy'].count()    
                if temp_min<0:
                    daily["tmin"] = True
                if temp_max>350:
                    daily["tmax"] = True
                if vv >0:
                    daily["view"] = True
                if RR >0:
                    daily["rain"] = True
                if wind >0:
                    daily["wind"] = True
                dailylist.append(daily)
        return dailylist
    def rain_data(self,start,end,station_data):
        '''返回点击绘图所需的数据'''
        # 采集数据 可以是sql
        station_all = station_data
        grouped_tTime = station_all.groupby('IIiii')
        points = []
        table_data = []  
        for i in grouped_tTime.size().index:
            data = grouped_tTime.get_group(i)
            RR = data[(data['RR'] > 0.0) & (data['RR'] < 8888)]['RR'].sum()/10.0
            if RR > 0:
                single = {
                    "type": "Feature",
                    "properties": {
                        "value": str(RR)
                    },
                    "geometry": {
                        "type": "Point",
                        "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                    }
                }
                points.append(single)  
                # 采集marker和表格的数据
                rain = data.sort_values(by="tTime")["RR"].to_list()
                time = data.sort_values(by="tTime")["tTime"].to_list()
                ## 自己定义表格的数据形式
                single_rain = {
                    "IIiii":data['IIiii'].iloc[0],
                    "county":data['county'].iloc[0],
                    "town":data['Town'].iloc[0],
                    "StationName":data['StationName'].iloc[0],
                    "RR":RR,
                    "lat":data['lat'].iloc[0],
                    "lon":data['lon'].iloc[0],
                    "height":data['Height'].iloc[0],
                    "rain_list":rain,
                    "time_list":time
                }
                table_data.append(single_rain)  
        return points
    def index_data(self):
        '''返回所有数据'''
        city = "taizhou"
        #station_all = self.read_csv()
        station_all = self.sql_data()
        daily_btn_list = self.day_button(city,station_all)
        grouped_tTime = station_all.groupby('IIiii')
        table_data = []  
        points = []
        for i in grouped_tTime.size().index:
            data = grouped_tTime.get_group(i)
            time = data.sort_values(by="tTime")["tTime"].to_list()
            RR = data[(data['RR'] > 0.0) & (data['RR'] < 8888)]['RR'].sum()/10.0
            tmin = data[(data['T'] >-400) & (data['T'] < 8888)]['T'].min()/10.0
            tmax = data[(data['T'] >-400) & (data['T'] < 8888)]['T'].max()/10.0
            vv = data[(data['VV'] >0) & (data['VV'] < 1000)]['VV'].min()
            wind = data[data['fFy'] > 180]['fFy'].max()/10.0
            index =  data[data['fFy'] == data['fFy'].max()].index.tolist()[0]
            #print(index,"---",wind,"--",data['dFy'][index])
            #deg = data[data['fFy'] == data['fFy'].max()]['dFy'].iloc[0]
            deg = data['dFy'][index]
            rain_data = {
                "type": "Feature",
                "properties": {
                    "value": str(RR)
                },
                "geometry": {
                    "type": "Point",
                    "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                }
            }        
            # 雨
            if np.isnan(RR):
                RR=-9999.0
                rain = False
            else:
                # rain_data = {
                #     "type": "Feature",
                #     "properties": {
                #         "value": str(RR)
                #     },
                #     "geometry": {
                #         "type": "Point",
                #         "coordinates": [data['lon'].iloc[0], data['lat'].iloc[0]]
                #     }
                # }
                # points.append(rain_data)
                rain = data.sort_values(by="tTime")["RR"].to_list()
            # 风
            if np.isnan(wind):
                wind=-9999.0
                fFy = False
                dFy = False
            else:
                fFy = data.sort_values(by="tTime")["fFy"].to_list()
                dFy = data.sort_values(by="tTime")["dFy"].to_list()
            # 温
            if np.isnan(tmax):
                tmax=-9999.0
                tx = False
            else:
                tx = data.sort_values(by="tTime")["Tx"].to_list()
            if np.isnan(tmin):
                tmin=-9999.0
                tn = False
            else:
                tn = data.sort_values(by="tTime")["Tn"].to_list()
            # 雾
            if np.isnan(vv):
                vv=-9999.0
                view = False
            else:
                view = data.sort_values(by="tTime")["VV"].to_list()
            single = {
                "IIiii":str(data['IIiii'].iloc[0]),
                "county":str(data['county'].iloc[0]),
                "town":str(data['Town'].iloc[0]),
                "StationName":str(data['StationName'].iloc[0]),
                "fFy":str(wind),
                "dFy":str(deg),
                "RR":str(RR),
                "Tx":str(tmax),
                "Tn":str(tmin),
                "VV":str(vv),
                "lat":str(data['lat'].iloc[0]),
                "lon":str(data['lon'].iloc[0]),
                "rain_list":rain,
                "tmax_list":tx,
                "tmin_list":tn,
                "fFy_list":fFy,
                "dFy_list":dFy,
                "view_list":view,
                "time_list":time
                }
            table_data.append(single)
        return table_data,points,daily_btn_list
